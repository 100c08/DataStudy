# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.rcParams['font.family'] = 'AppleGothic'

# 파일 경로 설정
file_path = "/Users/damien/Desktop/금융연구회/24-2/DSAI 스터디/lending_club_2020_train.csv"

# CSV 파일을 pandas 데이터프레임으로 읽기
data = pd.read_csv(file_path)

data
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2700309099.py:13: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
#                 id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0        124989905     6000.0       6000.0           6000.0   36 months
# 1        139665484    35000.0      35000.0          35000.0   60 months
# 2         84253847    23200.0      23200.0          23200.0   60 months
# 3        126296074     4500.0       4500.0           4500.0   36 months
# 4        148913312    15000.0      15000.0          15000.0   36 months
# ...            ...        ...          ...              ...         ...
# 1755290   12987407     3600.0       3600.0           3600.0   36 months
# 1755291   44299336    19000.0      19000.0          18875.0   36 months
# 1755292    5205034     9600.0       9600.0           9600.0   36 months
# 1755293  128261912    24000.0      24000.0          24000.0   36 months
# 1755294  100046460    14400.0      14400.0          14400.0   60 months
#
#         int_rate  installment grade sub_grade             emp_title  ...  \
# 0          7.97%       187.94     A        A5               Teacher  ...
# 1         14.47%       822.95     C        C2    Product Specialist  ...
# 2         24.99%       680.82     E        E4    Production Foreman  ...
# 3          9.93%       145.06     B        B2        Office Manager  ...
# 4         16.40%       530.33     C        C4             Secretary  ...
# ...          ...          ...   ...       ...                   ...  ...
# 1755290   19.99%       133.78     E        E1              Manager   ...
# 1755291    6.68%       583.89     A        A3      Systems Engineer  ...
# 1755292   14.33%       329.65     C        C1  ESS Support services  ...
# 1755293    7.35%       744.90     A        A4       sales associate  ...
# 1755294   13.49%       331.27     C        C2    Operations Manager  ...
#
#         hardship_start_date hardship_end_date  payment_plan_start_date  \
# 0                       NaN               NaN                      NaN
# 1                       NaN               NaN                      NaN
# 2                       NaN               NaN                      NaN
# 3                       NaN               NaN                      NaN
# 4                  May-2020          Jul-2020                 May-2020
# ...                     ...               ...                      ...
# 1755290                 NaN               NaN                      NaN
# 1755291                 NaN               NaN                      NaN
# 1755292                 NaN               NaN                      NaN
# 1755293                 NaN               NaN                      NaN
# 1755294                 NaN               NaN                      NaN
#
#         hardship_length hardship_dpd hardship_loan_status  \
# 0                   NaN          NaN                  NaN
# 1                   NaN          NaN                  NaN
# 2                   NaN          NaN                  NaN
# 3                   NaN          NaN                  NaN
# 4                   2.0          0.0               ACTIVE
# ...                 ...          ...                  ...
# 1755290             NaN          NaN                  NaN
# 1755291             NaN          NaN                  NaN
# 1755292             NaN          NaN                  NaN
# 1755293             NaN          NaN                  NaN
# 1755294             NaN          NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                           413.83
# ...                                            ...
# 1755290                                        NaN
# 1755291                                        NaN
# 1755292                                        NaN
# 1755293                                        NaN
# 1755294                                        NaN
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                             11025.25                        54.62
# ...                                ...                          ...
# 1755290                            NaN                          NaN
# 1755291                            NaN                          NaN
# 1755292                            NaN                          NaN
# 1755293                            NaN                          NaN
# 1755294                            NaN                          NaN
#
#         debt_settlement_flag
# 0                          N
# 1                          N
# 2                          Y
# 3                          N
# 4                          N
# ...                      ...
# 1755290                    N
# 1755291                    N
# 1755292                    N
# 1755293                    N
# 1755294                    N
#
# [1755295 rows x 141 columns]

# %%
# 영어 컬럼명을 한글로 변환하기 위한 매핑 사전
column_mapping = {
    'acc_now_delinq': '현재 연체 계좌 수',
    'acc_open_past_24mths': '최근 24개월간 개설된 계좌 수',
    'addr_state': '주소 상태',
    'all_util': '모든 거래의 잔액 대비 한도 비율',
    'annual_inc': '연간 소득',
    'annual_inc_joint': '연간 공동 소득',
    'application_type': '신청 유형',
    'avg_cur_bal': '평균 현재 잔액',
    'bc_open_to_buy': '은행카드 사용 가능 금액',
    'bc_util': '은행카드 한도 대비 사용 비율',
    'chargeoff_within_12_mths': '지난 12개월간 차감 횟수',
    'collection_recovery_fee': '차감 후 회수 수수료',
    'collections_12_mths_ex_med': '지난 12개월간 (의료 제외) 추심 횟수',
    'delinq_2yrs': '지난 2년간 30일 이상 연체된 계좌 수',
    'delinq_amnt': '현재 연체된 계좌의 연체 금액',
    'desc': '대출 설명',
    'dti': '부채 대비 소득 비율',
    'dti_joint': '공동 신청인의 부채 대비 소득 비율',
    'earliest_cr_line': '최초 신용 계좌 개설일',
    'emp_length': '근무 기간 (년)',
    'emp_title': '직업명',
    'fico_range_high': 'FICO 상한선',
    'fico_range_low': 'FICO 하한선',
    'funded_amnt': '대출 금액',
    'funded_amnt_inv': '투자자별 대출 금액',
    'grade': '등급',
    'home_ownership': '주택 소유 상태',
    'id': '고유 ID',
    'il_util': '할부 계좌 한도 대비 사용 비율',
    'initial_list_status': '초기 상장 상태',
    'inq_fi': '금융 조회 수',
    'inq_last_12m': '지난 12개월간 조회 수',
    'inq_last_6mths': '지난 6개월간 조회 수',
    'installment': '월 상환액',
    'int_rate': '이자율',
    'issue_d': '발행일',
    'last_credit_pull_d': '최근 신용 조회일',
    'last_fico_range_high': '최근 FICO 상한선',
    'last_fico_range_low': '최근 FICO 하한선',
    'last_pymnt_amnt': '최근 지급된 금액',
    'last_pymnt_d': '최근 지급일',
    'loan_amnt': '대출 신청 금액',
    'loan_status': '대출 상태',
    'max_bal_bc': '최대 은행카드 잔액',
    'member_id': '회원 ID',
    'mo_sin_old_il_acct': '가장 오래된 할부 계좌 개설 후 월 수',
    'mo_sin_old_rev_tl_op': '가장 오래된 회전 계좌 개설 후 월 수',
    'mo_sin_rcnt_rev_tl_op': '최근 회전 계좌 개설 후 월 수',
    'mo_sin_rcnt_tl': '최근 계좌 개설 후 월 수',
    'mort_acc': '모기지 계좌 수',
    'mths_since_last_delinq': '최근 연체 후 경과 개월 수',
    'mths_since_last_major_derog': '최근 90일 이상 연체 후 경과 개월 수',
    'mths_since_last_record': '최근 기록 후 경과 개월 수',
    'mths_since_rcnt_il': '최근 할부 계좌 개설 후 개월 수',
    'mths_since_recent_bc': '최근 은행카드 계좌 개설 후 개월 수',
    'mths_since_recent_bc_dlq': '최근 은행카드 연체 후 개월 수',
    'mths_since_recent_inq': '최근 조회 후 개월 수',
    'mths_since_recent_revol_delinq': '최근 회전 계좌 연체 후 개월 수',
    'next_pymnt_d': '다음 예정 상환일',
    'num_accts_ever_120_pd': '120일 이상 연체된 계좌 수',
    'num_actv_bc_tl': '활성 은행카드 계좌 수',
    'num_actv_rev_tl': '활성 회전 계좌 수',
    'num_bc_sats': '만족스러운 은행카드 계좌 수',
    'num_bc_tl': '은행카드 계좌 수',
    'num_il_tl': '할부 계좌 수',
    'num_op_rev_tl': '활성 회전 계좌 수',
    'num_rev_accts': '회전 계좌 수',
    'num_rev_tl_bal_gt_0': '잔액이 0보다 큰 회전 계좌 수',
    'num_sats': '만족스러운 계좌 수',
    'num_tl_120dpd_2m': '최근 2개월간 120일 이상 연체된 계좌 수',
    'num_tl_30dpd': '현재 30일 이상 연체된 계좌 수',
    'num_tl_90g_dpd_24m': '최근 24개월간 90일 이상 연체된 계좌 수',
    'num_tl_op_past_12m': '지난 12개월간 개설된 계좌 수',
    'open_acc': '현재 활성 신용 계좌 수',
    'open_acc_6m': '지난 6개월간 활성 신용 계좌 수',
    'open_il_12m': '지난 12개월간 할부 계좌 개설 수',
    'open_il_24m': '지난 24개월간 할부 계좌 개설 수',
    'open_act_il': '활성 할부 계좌 수',
    'open_rv_12m': '지난 12개월간 회전 계좌 개설 수',
    'open_rv_24m': '지난 24개월간 회전 계좌 개설 수',
    'out_prncp': '잔여 원금',
    'out_prncp_inv': '투자자별 잔여 원금',
    'pct_tl_nvr_dlq': '연체 경험이 없는 거래 비율',
    'percent_bc_gt_75': '한도 75% 초과 은행카드 계좌 비율',
    'policy_code': '정책 코드',
    'pub_rec': '공공 기록 수',
    'pub_rec_bankruptcies': '공공 기록 파산 수',
    'purpose': '대출 목적',
    'pymnt_plan': '상환 계획 여부',
    'recoveries': '차감 후 회수 금액',
    'revol_bal': '회전 신용 잔액',
    'revol_util': '회전 계좌 사용 비율',
    'sub_grade': '하위 등급',
    'tax_liens': '세금 유치권 수',
    'term': '대출 기간',
    'title': '대출 제목',
    'tot_coll_amt': '총 추심 금액',
    'tot_cur_bal': '총 현재 잔액',
    'tot_hi_cred_lim': '총 고신용 한도',
    'total_acc': '총 계좌 수',
    'total_bal_ex_mort': '모기지 제외 총 잔액',
    'total_bal_il': '할부 계좌 총 잔액',
    'total_bc_limit': '총 은행카드 한도',
    'total_cu_tl': '금융 거래 계좌 수',
    'total_il_high_credit_limit': '총 할부 계좌 고신용 한도',
    'total_pymnt': '총 지급 금액',
    'total_pymnt_inv': '투자자별 총 지급 금액',
    'total_rec_int': '지급된 이자 총액',
    'total_rec_late_fee': '지급된 연체 수수료 총액',
    'total_rec_prncp': '지급된 원금 총액',
    'total_rev_hi_lim': '회전 신용 고한도 총액',
    'verification_status': '소득 검증 상태',
    'verified_status_joint': '공동 소득 검증 상태',
    'zip_code': '우편번호',
    'revol_bal_joint': '공동 대출자의 회전 신용 잔액',
    'sec_app_fico_range_low': '부차 신청자 FICO 하한선',
    'sec_app_fico_range_high': '부차 신청자 FICO 상한선',
    'sec_app_earliest_cr_line': '부차 신청자 최초 신용 계좌 개설일',
    'sec_app_inq_last_6mths': '부차 신청자 최근 6개월간 조회 수',
    'sec_app_mort_acc': '부차 신청자 모기지 계좌 수',
    'sec_app_open_acc': '부차 신청자 활성 계좌 수',
    'sec_app_revol_util': '부차 신청자 회전 신용 한도 대비 사용 비율',
    'sec_app_open_act_il': '부차 신청자 활성 할부 계좌 수',
    'sec_app_num_rev_accts': '부차 신청자 회전 계좌 수',
    'sec_app_chargeoff_within_12_mths': '부차 신청자 지난 12개월간 차감 횟수',
    'sec_app_collections_12_mths_ex_med': '부차 신청자 지난 12개월간 (의료 제외) 추심 횟수',
    'sec_app_mths_since_last_major_derog': '부차 신청자 최근 90일 이상 연체 후 경과 개월 수',
    'hardship_flag': '고난 계획 여부',
    'hardship_type': '고난 계획 유형',
    'hardship_reason': '고난 계획 이유',
    'hardship_status': '고난 계획 상태',
    'deferral_term': '고난 기간',
    'hardship_amount': '고난 기간 동안의 이자 지급 금액',
    'hardship_start_date': '고난 계획 시작일',
    'hardship_end_date': '고난 계획 종료일',
    'payment_plan_start_date': '상환 계획 시작일',
    'hardship_length': '고난 계획 기간',
    'hardship_dpd': '고난 계획 시작일 기준 연체 일수',
    'hardship_loan_status': '고난 계획 시작일 기준 대출 상태',
    'orig_projected_additional_accrued_interest': '고난 계획 시작일 기준 예상 추가 이자',
    'hardship_payoff_balance_amount': '고난 계획 시작일 기준 상환 잔액',
    'hardship_last_payment_amount': '고난 계획 시작일 기준 최근 지급 금액',
    'disbursement_method': '대출 지급 방식',
    'debt_settlement_flag': '채무 조정 여부',
    'debt_settlement_flag_date': '채무 조정 플래그 설정 날짜',
    'settlement_status': '채무 조정 상태',
    'settlement_date': '채무 조정일',
    'settlement_amount': '채무 조정 금액',
    'settlement_percentage': '채무 조정 비율',
    'settlement_term': '채무 조정 기간'
}

# 컬럼 이름을 한글로 변경
data.rename(columns=column_mapping, inplace=True)

data
# Out:
#              고유 ID  대출 신청 금액    대출 금액  투자자별 대출 금액       대출 기간      이자율  \
# 0        124989905    6000.0   6000.0      6000.0   36 months    7.97%
# 1        139665484   35000.0  35000.0     35000.0   60 months   14.47%
# 2         84253847   23200.0  23200.0     23200.0   60 months   24.99%
# 3        126296074    4500.0   4500.0      4500.0   36 months    9.93%
# 4        148913312   15000.0  15000.0     15000.0   36 months   16.40%
# ...            ...       ...      ...         ...         ...      ...
# 1755290   12987407    3600.0   3600.0      3600.0   36 months   19.99%
# 1755291   44299336   19000.0  19000.0     18875.0   36 months    6.68%
# 1755292    5205034    9600.0   9600.0      9600.0   36 months   14.33%
# 1755293  128261912   24000.0  24000.0     24000.0   36 months    7.35%
# 1755294  100046460   14400.0  14400.0     14400.0   60 months   13.49%
#
#           월 상환액 등급 하위 등급                   직업명  ... 고난 계획 시작일 고난 계획 종료일  \
# 0        187.94  A    A5               Teacher  ...       NaN       NaN
# 1        822.95  C    C2    Product Specialist  ...       NaN       NaN
# 2        680.82  E    E4    Production Foreman  ...       NaN       NaN
# 3        145.06  B    B2        Office Manager  ...       NaN       NaN
# 4        530.33  C    C4             Secretary  ...  May-2020  Jul-2020
# ...         ... ..   ...                   ...  ...       ...       ...
# 1755290  133.78  E    E1              Manager   ...       NaN       NaN
# 1755291  583.89  A    A3      Systems Engineer  ...       NaN       NaN
# 1755292  329.65  C    C1  ESS Support services  ...       NaN       NaN
# 1755293  744.90  A    A4       sales associate  ...       NaN       NaN
# 1755294  331.27  C    C2    Operations Manager  ...       NaN       NaN
#
#          상환 계획 시작일 고난 계획 기간 고난 계획 시작일 기준 연체 일수 고난 계획 시작일 기준 대출 상태  \
# 0              NaN      NaN                NaN                NaN
# 1              NaN      NaN                NaN                NaN
# 2              NaN      NaN                NaN                NaN
# 3              NaN      NaN                NaN                NaN
# 4         May-2020      2.0                0.0             ACTIVE
# ...            ...      ...                ...                ...
# 1755290        NaN      NaN                NaN                NaN
# 1755291        NaN      NaN                NaN                NaN
# 1755292        NaN      NaN                NaN                NaN
# 1755293        NaN      NaN                NaN                NaN
# 1755294        NaN      NaN                NaN                NaN
#
#         고난 계획 시작일 기준 예상 추가 이자 고난 계획 시작일 기준 상환 잔액 고난 계획 시작일 기준 최근 지급 금액  \
# 0                         NaN                NaN                   NaN
# 1                         NaN                NaN                   NaN
# 2                         NaN                NaN                   NaN
# 3                         NaN                NaN                   NaN
# 4                      413.83           11025.25                 54.62
# ...                       ...                ...                   ...
# 1755290                   NaN                NaN                   NaN
# 1755291                   NaN                NaN                   NaN
# 1755292                   NaN                NaN                   NaN
# 1755293                   NaN                NaN                   NaN
# 1755294                   NaN                NaN                   NaN
#
#         채무 조정 여부
# 0              N
# 1              N
# 2              Y
# 3              N
# 4              N
# ...          ...
# 1755290        N
# 1755291        N
# 1755292        N
# 1755293        N
# 1755294        N
#
# [1755295 rows x 141 columns]

# %%
# 출력 가능한 최대 열 및 행 수를 확장
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 데이터프레임의 각 칼럼의 데이터 타입 확인
print(data.dtypes)
# Out:
# 고유 ID                             object
# 대출 신청 금액                         float64
# 대출 금액                            float64
# 투자자별 대출 금액                       float64
# 대출 기간                             object
# 이자율                               object
# 월 상환액                            float64
# 등급                                object
# 하위 등급                             object
# 직업명                               object
# 근무 기간 (년)                         object
# 주택 소유 상태                          object
# 연간 소득                            float64
# 소득 검증 상태                          object
# 발행일                               object
# 대출 상태                             object
# 상환 계획 여부                          object
# url                               object
# 대출 목적                             object
# 대출 제목                             object
# 우편번호                              object
# 주소 상태                             object
# 부채 대비 소득 비율                      float64
# 지난 2년간 30일 이상 연체된 계좌 수           float64
# 최초 신용 계좌 개설일                      object
# FICO 하한선                         float64
# FICO 상한선                         float64
# 지난 6개월간 조회 수                     float64
# 최근 연체 후 경과 개월 수                  float64
# 최근 기록 후 경과 개월 수                  float64
# 현재 활성 신용 계좌 수                    float64
# 공공 기록 수                          float64
# 회전 신용 잔액                         float64
# 회전 계좌 사용 비율                       object
# 총 계좌 수                           float64
# 초기 상장 상태                          object
# 잔여 원금                            float64
# 투자자별 잔여 원금                       float64
# 총 지급 금액                          float64
# 투자자별 총 지급 금액                     float64
# 지급된 원금 총액                        float64
# 지급된 이자 총액                        float64
# 지급된 연체 수수료 총액                    float64
# 차감 후 회수 금액                       float64
# 차감 후 회수 수수료                      float64
# 최근 지급일                            object
# 최근 지급된 금액                        float64
# 다음 예정 상환일                         object
# 최근 신용 조회일                         object
# 최근 FICO 상한선                      float64
# 최근 FICO 하한선                      float64
# 지난 12개월간 (의료 제외) 추심 횟수           float64
# 최근 90일 이상 연체 후 경과 개월 수           float64
# 정책 코드                            float64
# 신청 유형                             object
# 연간 공동 소득                         float64
# 공동 신청인의 부채 대비 소득 비율              float64
# verification_status_joint         object
# 현재 연체 계좌 수                       float64
# 총 추심 금액                          float64
# 총 현재 잔액                          float64
# 지난 6개월간 활성 신용 계좌 수               float64
# 활성 할부 계좌 수                       float64
# 지난 12개월간 할부 계좌 개설 수              float64
# 지난 24개월간 할부 계좌 개설 수              float64
# 최근 할부 계좌 개설 후 개월 수               float64
# 할부 계좌 총 잔액                       float64
# 할부 계좌 한도 대비 사용 비율                float64
# 지난 12개월간 회전 계좌 개설 수              float64
# 지난 24개월간 회전 계좌 개설 수              float64
# 최대 은행카드 잔액                       float64
# 모든 거래의 잔액 대비 한도 비율               float64
# 회전 신용 고한도 총액                     float64
# 금융 조회 수                          float64
# 금융 거래 계좌 수                       float64
# 지난 12개월간 조회 수                    float64
# 최근 24개월간 개설된 계좌 수                float64
# 평균 현재 잔액                         float64
# 은행카드 사용 가능 금액                    float64
# 은행카드 한도 대비 사용 비율                 float64
# 지난 12개월간 차감 횟수                   float64
# 현재 연체된 계좌의 연체 금액                 float64
# 가장 오래된 할부 계좌 개설 후 월 수            float64
# 가장 오래된 회전 계좌 개설 후 월 수            float64
# 최근 회전 계좌 개설 후 월 수                float64
# 최근 계좌 개설 후 월 수                   float64
# 모기지 계좌 수                         float64
# 최근 은행카드 계좌 개설 후 개월 수             float64
# 최근 은행카드 연체 후 개월 수                float64
# 최근 조회 후 개월 수                     float64
# 최근 회전 계좌 연체 후 개월 수               float64
# 120일 이상 연체된 계좌 수                 float64
# 활성 은행카드 계좌 수                     float64
# 활성 회전 계좌 수                       float64
# 만족스러운 은행카드 계좌 수                  float64
# 은행카드 계좌 수                        float64
# 할부 계좌 수                          float64
# 활성 회전 계좌 수                       float64
# 회전 계좌 수                          float64
# 잔액이 0보다 큰 회전 계좌 수                float64
# 만족스러운 계좌 수                       float64
# 최근 2개월간 120일 이상 연체된 계좌 수         float64
# 현재 30일 이상 연체된 계좌 수               float64
# 최근 24개월간 90일 이상 연체된 계좌 수         float64
# 지난 12개월간 개설된 계좌 수                float64
# 연체 경험이 없는 거래 비율                  float64
# 한도 75% 초과 은행카드 계좌 비율             float64
# 공공 기록 파산 수                       float64
# 세금 유치권 수                         float64
# 총 고신용 한도                         float64
# 모기지 제외 총 잔액                      float64
# 총 은행카드 한도                        float64
# 총 할부 계좌 고신용 한도                   float64
# 공동 대출자의 회전 신용 잔액                 float64
# 부차 신청자 FICO 하한선                  float64
# 부차 신청자 FICO 상한선                  float64
# 부차 신청자 최초 신용 계좌 개설일               object
# 부차 신청자 최근 6개월간 조회 수              float64
# 부차 신청자 모기지 계좌 수                  float64
# 부차 신청자 활성 계좌 수                   float64
# 부차 신청자 회전 신용 한도 대비 사용 비율         float64
# 부차 신청자 활성 할부 계좌 수                float64
# 부차 신청자 회전 계좌 수                   float64
# 부차 신청자 지난 12개월간 차감 횟수            float64
# 부차 신청자 지난 12개월간 (의료 제외) 추심 횟수    float64
# 고난 계획 여부                          object
# 고난 계획 유형                          object
# 고난 계획 이유                          object
# 고난 계획 상태                          object
# 고난 기간                            float64
# 고난 기간 동안의 이자 지급 금액               float64
# 고난 계획 시작일                         object
# 고난 계획 종료일                         object
# 상환 계획 시작일                         object
# 고난 계획 기간                         float64
# 고난 계획 시작일 기준 연체 일수               float64
# 고난 계획 시작일 기준 대출 상태                object
# 고난 계획 시작일 기준 예상 추가 이자            float64
# 고난 계획 시작일 기준 상환 잔액               float64
# 고난 계획 시작일 기준 최근 지급 금액            float64
# 채무 조정 여부                          object
# dtype: object

# %%
# 고유 ID가 저장된 열이 'id'라고 가정하고 고유값 개수 확인
unique_id_count = data['고유 ID'].nunique()

# 고유 아이디 개수 출력
print(f"고유 아이디 개수: {unique_id_count}")
# Out:
# 고유 아이디 개수: 1755295

# %%
# 데이터프레임의 칼럼명 리스트 출력
column_names = data.columns.tolist()

# 칼럼명 리스트 출력
print(column_names)
# Out:
# ['고유 ID', '대출 신청 금액', '대출 금액', '투자자별 대출 금액', '대출 기간', '이자율', '월 상환액', '등급', '하위 등급', '직업명', '근무 기간 (년)', '주택 소유 상태', '연간 소득', '소득 검증 상태', '발행일', '대출 상태', '상환 계획 여부', 'url', '대출 목적', '대출 제목', '우편번호', '주소 상태', '부채 대비 소득 비율', '지난 2년간 30일 이상 연체된 계좌 수', '최초 신용 계좌 개설일', 'FICO 하한선', 'FICO 상한선', '지난 6개월간 조회 수', '최근 연체 후 경과 개월 수', '최근 기록 후 경과 개월 수', '현재 활성 신용 계좌 수', '공공 기록 수', '회전 신용 잔액', '회전 계좌 사용 비율', '총 계좌 수', '초기 상장 상태', '잔여 원금', '투자자별 잔여 원금', '총 지급 금액', '투자자별 총 지급 금액', '지급된 원금 총액', '지급된 이자 총액', '지급된 연체 수수료 총액', '차감 후 회수 금액', '차감 후 회수 수수료', '최근 지급일', '최근 지급된 금액', '다음 예정 상환일', '최근 신용 조회일', '최근 FICO 상한선', '최근 FICO 하한선', '지난 12개월간 (의료 제외) 추심 횟수', '최근 90일 이상 연체 후 경과 개월 수', '정책 코드', '신청 유형', '연간 공동 소득', '공동 신청인의 부채 대비 소득 비율', 'verification_status_joint', '현재 연체 계좌 수', '총 추심 금액', '총 현재 잔액', '지난 6개월간 활성 신용 계좌 수', '활성 할부 계좌 수', '지난 12개월간 할부 계좌 개설 수', '지난 24개월간 할부 계좌 개설 수', '최근 할부 계좌 개설 후 개월 수', '할부 계좌 총 잔액', '할부 계좌 한도 대비 사용 비율', '지난 12개월간 회전 계좌 개설 수', '지난 24개월간 회전 계좌 개설 수', '최대 은행카드 잔액', '모든 거래의 잔액 대비 한도 비율', '회전 신용 고한도 총액', '금융 조회 수', '금융 거래 계좌 수', '지난 12개월간 조회 수', '최근 24개월간 개설된 계좌 수', '평균 현재 잔액', '은행카드 사용 가능 금액', '은행카드 한도 대비 사용 비율', '지난 12개월간 차감 횟수', '현재 연체된 계좌의 연체 금액', '가장 오래된 할부 계좌 개설 후 월 수', '가장 오래된 회전 계좌 개설 후 월 수', '최근 회전 계좌 개설 후 월 수', '최근 계좌 개설 후 월 수', '모기지 계좌 수', '최근 은행카드 계좌 개설 후 개월 수', '최근 은행카드 연체 후 개월 수', '최근 조회 후 개월 수', '최근 회전 계좌 연체 후 개월 수', '120일 이상 연체된 계좌 수', '활성 은행카드 계좌 수', '활성 회전 계좌 수', '만족스러운 은행카드 계좌 수', '은행카드 계좌 수', '할부 계좌 수', '활성 회전 계좌 수', '회전 계좌 수', '잔액이 0보다 큰 회전 계좌 수', '만족스러운 계좌 수', '최근 2개월간 120일 이상 연체된 계좌 수', '현재 30일 이상 연체된 계좌 수', '최근 24개월간 90일 이상 연체된 계좌 수', '지난 12개월간 개설된 계좌 수', '연체 경험이 없는 거래 비율', '한도 75% 초과 은행카드 계좌 비율', '공공 기록 파산 수', '세금 유치권 수', '총 고신용 한도', '모기지 제외 총 잔액', '총 은행카드 한도', '총 할부 계좌 고신용 한도', '공동 대출자의 회전 신용 잔액', '부차 신청자 FICO 하한선', '부차 신청자 FICO 상한선', '부차 신청자 최초 신용 계좌 개설일', '부차 신청자 최근 6개월간 조회 수', '부차 신청자 모기지 계좌 수', '부차 신청자 활성 계좌 수', '부차 신청자 회전 신용 한도 대비 사용 비율', '부차 신청자 활성 할부 계좌 수', '부차 신청자 회전 계좌 수', '부차 신청자 지난 12개월간 차감 횟수', '부차 신청자 지난 12개월간 (의료 제외) 추심 횟수', '고난 계획 여부', '고난 계획 유형', '고난 계획 이유', '고난 계획 상태', '고난 기간', '고난 기간 동안의 이자 지급 금액', '고난 계획 시작일', '고난 계획 종료일', '상환 계획 시작일', '고난 계획 기간', '고난 계획 시작일 기준 연체 일수', '고난 계획 시작일 기준 대출 상태', '고난 계획 시작일 기준 예상 추가 이자', '고난 계획 시작일 기준 상환 잔액', '고난 계획 시작일 기준 최근 지급 금액', '채무 조정 여부']

# %%
import matplotlib.pyplot as plt

# '대출 상태' 컬럼의 값에 대한 빈도 계산
loan_status_counts = data['대출 상태'].value_counts()

# 원그래프 그리기
plt.figure(figsize=(8, 8))
plt.pie(loan_status_counts, labels=loan_status_counts.index, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.title('대출 상태 비율')
plt.show()

# %%
# '대출 상태' 칼럼의 값에 대한 빈도 계산 및 출력
loan_status_counts = data['대출 상태'].value_counts()

# 결과 출력
print(loan_status_counts)
# Out:
# 대출 상태
# Fully Paid                                             898522
# Current                                                618688
# Charged Off                                            217366
# Late (31-120 days)                                       9840
# In Grace Period                                          6049
# Late (16-30 days)                                        1620
# Issued                                                   1258
# Does not meet the credit policy. Status:Fully Paid       1223
# Does not meet the credit policy. Status:Charged Off       460
# Default                                                   268
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# '대출 상태'를 '양호', '연체', 'Default'로 묶기 위한 매핑
status_mapping = {
    'Fully Paid': '양호',
    'Current': '양호',
    'Issued': '양호',
    'Does not meet the credit policy. Status: Fully Paid': '양호',
    'Late (31-120 days)': '연체',
    'Late (16-30 days)': '연체',
    'In Grace Period': '연체',
    'Charged Off': 'Default',
    'Does not meet the credit policy. Status: Charged Off': 'Default',
    'Default': 'Default'
}

# '대출 상태'에 따라 '양호', '연체', 'Default'로 재분류
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 각 그룹의 빈도수 계산
status_counts = data['대출 상태 그룹'].value_counts()

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff9999', '#99ff99'])
plt.title('대출 상태에 따른 분류 (양호, 연체, Default)')
plt.axis('equal')  # 원이 일그러지지 않도록
plt.show()

# %%
import matplotlib.pyplot as plt

# '대출 상태'를 '양호', '연체', 'Default'로 묶기 위한 매핑 (Current 제외)
status_mapping = {
    'Fully Paid': '양호',
    'Issued': '양호',
    'Does not meet the credit policy. Status: Fully Paid': '양호',
    'Late (31-120 days)': '연체',
    'Late (16-30 days)': '연체',
    'In Grace Period': '연체',
    'Charged Off': 'Default',
    'Does not meet the credit policy. Status: Charged Off': 'Default',
    'Default': 'Default'
}

# '대출 상태'에 따라 '양호', '연체', 'Default'로 재분류하고 'Current' 제거
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 'Current'를 제외한 데이터 필터링
filtered_data = data.dropna(subset=['대출 상태 그룹'])

# 각 그룹의 빈도수 계산
status_counts = filtered_data['대출 상태 그룹'].value_counts()

# 원형 그래프 그리기
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff9999', '#99ff99'])
plt.title('대출 상태에 따른 분류 (양호, 연체, Default)')
plt.axis('equal')  # 원이 일그러지지 않도록
plt.show()

# %%
# '대출 상태'를 '정상'과 '그 외'로 그룹화
data['대출 상태 그룹'] = data['대출 상태'].apply(lambda x: '정상' if x in ['Fully Paid', 'Current'] else '그 외')

# '대출 상태 그룹'과 '등급'에 대한 빈도수 계산
grouped_data = data.groupby(['대출 상태 그룹', '등급']).size().unstack()

# 시각화
plt.figure(figsize=(10, 6))
grouped_data.plot(kind='bar', stacked=True)

plt.title('대출 상태 그룹에 따른 등급 분포')
plt.xlabel('대출 상태 그룹')
plt.ylabel('빈도수')
plt.xticks(rotation=0)
plt.legend(title='등급')
plt.tight_layout()

# 그래프 출력
plt.show()

# %%
# '이자율' 칼럼의 데이터 타입 확인
print(data['이자율'].dtype)
# Out:
# object

# %%
# '이자율' 칼럼에서 상위 10개 값 출력
print(data['이자율'].head(10))
# Out:
# 0      7.97%
# 1     14.47%
# 2     24.99%
# 3      9.93%
# 4     16.40%
# 5      7.07%
# 6     10.42%
# 7      9.99%
# 8     17.97%
# 9      8.19%
# Name: 이자율, dtype: object

# %%
# '%' 기호를 제거하고, 숫자형(float)으로 변환한 후 100으로 나누어 소수로 변환
data['이자율'] = data['이자율'].str.replace('%', '').astype(float) / 100

# 변환 후 상위 10개 값 출력
print(data['이자율'].head(10))
# Out:
# 0    0.0797
# 1    0.1447
# 2    0.2499
# 3    0.0993
# 4    0.1640
# 5    0.0707
# 6    0.1042
# 7    0.0999
# 8    0.1797
# 9    0.0819
# Name: 이자율, dtype: float64

# %%
# '이자율' 컬럼의 통계적 수치를 출력
interest_rate_stats = data['이자율'].describe()

# 결과 출력
print(interest_rate_stats)
# Out:
# count    1.755294e+06
# mean     1.304374e-01
# std      4.859769e-02
# min      5.310000e-02
# 25%      9.170000e-02
# 50%      1.249000e-01
# 75%      1.599000e-01
# max      3.099000e-01
# Name: 이자율, dtype: float64

# %%
# 대출 상태를 '양호', '연체', 'Default'로 매핑
status_mapping = {
    'Fully Paid': '양호',
    'Current': '양호',
    'Issued': '양호',
    'Does not meet the credit policy. Status: Fully Paid': '양호',
    'Late (31-120 days)': '연체',
    'Late (16-30 days)': '연체',
    'In Grace Period': '연체',
    'Charged Off': 'Default',
    'Does not meet the credit policy. Status: Charged Off': 'Default',
    'Default': 'Default'
}

# '대출 상태'를 기준으로 '대출 상태 그룹'에 값을 매핑
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 매핑 후 결측값 확인
print(data['대출 상태 그룹'].isnull().sum())  # 결측값이 없도록 해야 함

# 부도 상태를 숫자로 매핑 ('양호' = 0, '연체' = 1, 'Default' = 2)
status_numeric_mapping = {'양호': 0, '연체': 1, 'Default': 2}
data['대출 상태 그룹'] = data['대출 상태 그룹'].map(status_numeric_mapping)

# 결측값 제거
filtered_data = data[['이자율', '대출 상태 그룹']].dropna()

# 상관관계 계산
correlation = filtered_data.corr()

# 상관관계 출력
print("이자율과 부도 상태 간의 상관관계:\n", correlation)

# 시각화
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('이자율과 부도 상태 간의 상관관계')
plt.show()
# Out:
# 1684
# 이자율과 부도 상태 간의 상관관계:
#                 이자율  대출 상태 그룹
# 이자율       1.000000  0.207474
# 대출 상태 그룹  0.207474  1.000000
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# '대출 상태'를 '양호', '연체', 'Default'로 매핑 (Current 제외)
status_mapping = {
    'Fully Paid': '양호',
    'Issued': '양호',
    'Does not meet the credit policy. Status: Fully Paid': '양호',
    'Late (31-120 days)': '연체',
    'Late (16-30 days)': '연체',
    'In Grace Period': '연체',
    'Charged Off': 'Default',
    'Does not meet the credit policy. Status: Charged Off': 'Default',
    'Default': 'Default'
}

# '대출 상태'를 기준으로 '대출 상태 그룹'에 값을 매핑
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 'Current' 상태를 제거한 데이터 필터링 (이것이 핵심입니다)
filtered_data = data[data['대출 상태'] != 'Current']

# 매핑 후 결측값 확인 (Current 제외)
print(f"매핑 후 결측값 개수: {filtered_data['대출 상태 그룹'].isnull().sum()}")  # 결측값 없음

# 부도 상태를 숫자로 매핑 ('양호' = 0, '연체' = 1, 'Default' = 2)
status_numeric_mapping = {'양호': 0, '연체': 1, 'Default': 2}
filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)

# 결측값 제거 후 상관관계 계산
final_filtered_data = filtered_data[['이자율', '대출 상태 그룹']].dropna()

# 상관관계 계산
correlation = final_filtered_data.corr()

# 상관관계 출력
print("이자율과 부도 상태 간의 상관관계 (Current 제외):\n", correlation)

# 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('이자율과 부도 상태 간의 상관관계 (Current 제외)')
plt.show()
# Out:
# 매핑 후 결측값 개수: 1684
# 이자율과 부도 상태 간의 상관관계 (Current 제외):
#                 이자율  대출 상태 그룹
# 이자율       1.000000  0.254016
# 대출 상태 그룹  0.254016  1.000000
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/3739016787.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 이자율 구간 나누기 (예: 5% 구간씩 나누기)
bins = [0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]
labels = ['0-5%', '5-10%', '10-15%', '15-20%', '20-25%', '25-30%']
data['이자율 구간'] = pd.cut(data['이자율'], bins=bins, labels=labels, right=False)

# 신용등급 순서를 지정 (A, B, C, D, E, F, G 순서)
grade_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# 신용등급별 이자율 구간 분포 시각화
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='이자율 구간', hue='등급', hue_order=grade_order, palette='Set2')

# 그래프 설정
plt.title('신용등급별 이자율 구간 분포')
plt.xlabel('이자율 구간')
plt.ylabel('빈도수')
plt.legend(title='등급')
plt.tight_layout()

# 그래프 출력
plt.show()

# %% [markdown]
# # 대출 시점에만 얻을 수 있는 코드 토대로 이자율이랑 히트맵 만들어보자

# %%
# '근무 기간 (년)' 칼럼의 데이터와 데이터 타입 출력
print(data['근무 기간 (년)'].head(10))  # 상위 10개 값 출력
print(f"\n'근무 기간 (년)' 데이터 타입: {data['근무 기간 (년)'].dtype}")
# Out:
# 0      2 years
# 1      2 years
# 2    10+ years
# 3    10+ years
# 4    10+ years
# 5          NaN
# 6      5 years
# 7    10+ years
# 8      5 years
# 9       1 year
# Name: 근무 기간 (년), dtype: object
#
# '근무 기간 (년)' 데이터 타입: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 필요한 칼럼들만 추리는 함수
def prepare_correlation_data(data):
    # 대출 신청 당시의 정보만 포함할 칼럼 목록
    columns_for_correlation = [
        '대출 신청 금액', '대출 금액', '대출 기간', '월 상환액', '등급', '근무 기간 (년)',
        '주택 소유 상태', '연간 소득', '부채 대비 소득 비율', 'FICO 하한선', 'FICO 상한선',
        '현재 활성 신용 계좌 수', '공공 기록 수', '회전 신용 잔액', '회전 계좌 사용 비율', '총 계좌 수', '이자율'
    ]
    
    # 이자율을 포함한 데이터프레임 생성
    correlation_data = data[columns_for_correlation].copy()
    
    return correlation_data

# 1. 칼럼 목록 추리기
correlation_data = prepare_correlation_data(data)

# 2. '근무 기간 (년)' 문자열을 숫자형으로 변환
correlation_data['근무 기간 (년)'] = data['근무 기간 (년)'].replace({
    '10+ years': '10', '< 1 year': '0.5'
}).str.extract('(\d+\.?\d*)').astype(float)

# 변환된 상위 10개 값과 데이터 타입 출력
print(correlation_data['근무 기간 (년)'].head(10))
print(f"\n'근무 기간 (년)' 데이터 타입: {correlation_data['근무 기간 (년)'].dtype}")

# 3. '회전 계좌 사용 비율'에서 '%' 기호를 제거하고 숫자로 변환
correlation_data['회전 계좌 사용 비율'] = data['회전 계좌 사용 비율'].str.replace('%', '').astype(float) / 100

# 4. '대출 기간', '등급', '주택 소유 상태' 등의 범주형 변수를 숫자로 변환
correlation_data['대출 기간'] = data['대출 기간'].map({' 36 months': 36, ' 60 months': 60})
correlation_data['등급'] = data['등급'].map({'A': 7, 'B': 6, 'C': 5, 'D': 4, 'E': 3, 'F': 2, 'G': 1})
correlation_data['주택 소유 상태'] = data['주택 소유 상태'].map({'RENT': 0, 'OWN': 1, 'MORTGAGE': 2})

# 5. 상관관계 계산
corr_matrix = correlation_data.corr(numeric_only=True)

# 6. 이자율과 다른 변수들과의 상관관계 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix[['이자율']].sort_values(by='이자율', ascending=False), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('이자율과 대출 신청 당시 변수들 간의 상관관계')
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\d'
# <>:25: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/311133078.py:25: SyntaxWarning: invalid escape sequence '\d'
#   }).str.extract('(\d+\.?\d*)').astype(float)
# 0     2.0
# 1     2.0
# 2    10.0
# 3    10.0
# 4    10.0
# 5     NaN
# 6     5.0
# 7    10.0
# 8     5.0
# 9     1.0
# Name: 근무 기간 (년), dtype: float64
#
# '근무 기간 (년)' 데이터 타입: float64
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **FICO 상한선**과 **FICO 하한선**은 **FICO 신용 점수**의 상한값과 하한값을 의미합니다. 대출을 신청할 때, 각 개인은 **FICO 신용 점수**라는 금융 신뢰도를 나타내는 점수를 가지고 있습니다. 이 점수는 대출자가 채무를 상환할 능력이나 의향을 나타내는 중요한 지표입니다.
#
# ### **FICO 점수란?**
# FICO 점수는 300점에서 850점 사이에서 매겨지며, 이 점수는 대출자의 신용도와 상환 가능성을 평가하는 중요한 기준이 됩니다. FICO 점수가 높을수록 대출자가 더 신용할 만한 사람으로 간주되며, 낮을수록 신용 리스크가 큰 것으로 평가됩니다.
#
# ### **FICO 상한선(FICO Range High)**
# - **FICO 상한선**은 해당 대출 신청 시 대출자의 신용 점수 범위에서 **최고 점수**를 나타냅니다.
# - 예를 들어, 대출자가 680에서 720 사이의 FICO 점수 범위를 가지고 있다면, 상한선은 720입니다.
#
# ### **FICO 하한선(FICO Range Low)**
# - **FICO 하한선**은 대출 신청 시 대출자의 신용 점수 범위에서 **최저 점수**를 나타냅니다.
# - 위 예에서 하한선은 680입니다.
#
# 따라서 대출 데이터에서 **FICO 상한선**과 **하한선**은 대출자의 FICO 신용 점수 범위를 나타내며, 이 점수는 대출자마다 달라질 수 있습니다. 대출 결정에 중요한 역할을 하며, 이자율 등 여러 대출 조건에 영향을 미칩니다.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# '신용등급'을 숫자로 매핑 ('A' = 1, 'B' = 2, ...)
grade_mapping = {
    'A': 1,
    'B': 2,
    'C': 3,
    'D': 4,
    'E': 5,
    'F': 6,
    'G': 7
}

# '신용등급'을 숫자로 변환
data['신용등급'] = data['등급'].map(grade_mapping)

# 'Current' 상태를 제거한 데이터 필터링
filtered_data = data[data['대출 상태'] != 'Current']

# '대출 상태 그룹'을 숫자로 변환 ('양호' = 0, '연체' = 1, 'Default' = 2)
status_numeric_mapping = {'양호': 0, '연체': 1, 'Default': 2}
filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)

# 결측값 제거
final_filtered_data = filtered_data[['신용등급', '대출 상태 그룹']].dropna()

# 상관관계 계산
correlation = final_filtered_data.corr()

# 상관관계 출력
print("신용등급과 대출 상태 그룹 간의 상관관계:\n", correlation)

# 상관관계 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('신용등급과 대출 상태 그룹 간의 상관관계')
plt.show()
# Out:
# 신용등급과 대출 상태 그룹 간의 상관관계:
#                신용등급  대출 상태 그룹
# 신용등급      1.000000  0.249818
# 대출 상태 그룹  0.249818  1.000000
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/1854611233.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 대출 특성 및 조건 관련 변수 (Loan Characteristics and Terms)
# 대출 자체의 조건이나 상태와 관련된 변수로, 대출 상환 가능성 평가에 중요합니다.
#
# loan_amnt: 대출 금액. 큰 대출 금액은 대출자의 재정 부담을 증가시킬 수 있음.
#
# funded_amnt: 대출에 실제로 할당된 금액.
#
# installment: 대출자가 매월 상환해야 하는 금액. 높은 월 상환 금액은 재정 부담 증가로 이어질 수 있음.
#
# int_rate: 대출 금리. 금리가 높으면 상환 부담이 커져 부도 가능성 증가.
#
# issue_d: 대출이 실행된 날짜.
#
# loan_status: 현재 대출 상태. 모델의 종속 변수로 사용될 수 있음.

# %%
# 대출 신청 금액, 이자율, 대출 기간, 월 상환액 데이터 확인
print(data[['대출 신청 금액', '이자율', '대출 기간', '월 상환액']].head())
# Out:
#    대출 신청 금액     이자율       대출 기간   월 상환액
# 0    6000.0  0.0797   36 months  187.94
# 1   35000.0  0.1447   60 months  822.95
# 2   23200.0  0.2499   60 months  680.82
# 3    4500.0  0.0993   36 months  145.06
# 4   15000.0  0.1640   36 months  530.33

# %%
import pandas as pd

# '대출 기간' 칼럼에서 'months'를 제거하고 숫자로 변환
data['대출 기간'] = data['대출 기간'].str.replace(' months', '').astype(float)

# 결측치가 있는 행을 제거하기 전에 각 칼럼의 데이터 상태를 다시 확인
print("대출 기간 데이터 타입 및 값:", data['대출 기간'].dtype, data['대출 기간'].unique())
print("이자율 데이터 타입 및 값:", data['이자율'].dtype, data['이자율'].unique())
print("대출 금액 데이터 타입 및 값:", data['대출 금액'].dtype, data['대출 금액'].unique())
print("월 상환액 데이터 타입 및 값:", data['월 상환액'].dtype, data['월 상환액'].unique())

# 결측치가 있는 행을 제거하기 전에, 몇 개의 데이터가 결측치가 있는지 확인
print("대출 기간 결측치 개수:", data['대출 기간'].isnull().sum())
print("이자율 결측치 개수:", data['이자율'].isnull().sum())
print("대출 금액 결측치 개수:", data['대출 금액'].isnull().sum())
print("월 상환액 결측치 개수:", data['월 상환액'].isnull().sum())

# 결측치가 있는 행 제거
data = data.dropna(subset=['대출 기간', '이자율', '대출 금액', '월 상환액'])

# 결측치 제거 후 데이터 상태 확인
if data.empty:
    print("데이터가 없습니다. 데이터를 확인하세요.")
else:
    # 월 상환액을 계산하는 함수
    def calculate_monthly_payment(row):
        loan_amnt = row['대출 금액']
        int_rate = row['이자율']
        term = row['대출 기간']
        
        # 월 이자율 계산 (연 이자율을 12로 나눔)
        monthly_rate = int_rate / 12
        
        # 월 상환액 계산 공식
        if monthly_rate > 0:
            monthly_payment = loan_amnt * (monthly_rate * (1 + monthly_rate) ** term) / ((1 + monthly_rate) ** term - 1)
        else:
            monthly_payment = loan_amnt / term  # 이자율이 0일 경우 단순 나누기
        
        return monthly_payment

    # 각 행에 대해 이론적으로 계산된 월 상환액 계산
    data['계산된 월 상환액'] = data.apply(calculate_monthly_payment, axis=1)

    # 실제 월 상환액과 이론적 월 상환액 간의 차이 계산
    data['차이'] = data['월 상환액'] - data['계산된 월 상환액']

    # 차이를 큰 순서대로 정렬
    sorted_difference = data['차이'].sort_values(ascending=False)

    # 결과 출력 (상위 5개)
    print(data[['대출 금액', '이자율', '대출 기간', '월 상환액', '계산된 월 상환액', '차이']].head())
    print("차이가 큰 상위 5개:\n", sorted_difference.head())
# Out:
# 대출 기간 데이터 타입 및 값: float64 [36. 60. nan]
# 이자율 데이터 타입 및 값: float64 [0.0797 0.1447 0.2499 0.0993 0.164  0.0707 0.1042 0.0999 0.1797 0.0819
#  0.1308 0.143  0.1999 0.1033 0.0846 0.1359 0.1799 0.1824 0.1199 0.0881
#  0.0735 0.1269 0.1015 0.1367 0.1709 0.1786 0.1399 0.1502 0.1855 0.1825
#  0.1504 0.1358 0.0699 0.1524 0.0956 0.1757 0.0756 0.124  0.1171 0.0649
#  0.1064 0.1465 0.1299 0.0916 0.2074 0.1081 0.1602 0.0762 0.1612 0.1229
#  0.1691 0.0532 0.0992 0.0702 0.1806 0.1402 0.0838 0.0789 0.1139 0.2245
#  0.1747 0.1449 0.1149 0.1699 0.158  0.0671 0.2089 0.1614 0.1262 0.3084
#  0.0818 0.109  0.0639 0.1727 0.2387 0.0646 0.0697 0.1499 0.0531 0.1131
#  0.1899 0.1531 0.2215 0.0902 0.1903 0.0593 0.1919 0.0721 0.1099 0.0724
#  0.2631 0.0899 0.1774 0.1105 0.2399 0.2055 0.1153 0.2145 0.1398 0.1561
#  0.0975 0.1091 0.1349 0.2185 0.2949 0.0971 0.1408 0.0672 0.1947 0.0839
#  0.1601 0.1407 0.1549 0.1102 0.0849 0.1433 0.2411 0.0769 0.1719 0.1155
#  0.154  0.2388 0.079  0.1416 0.2437 0.1678 0.1172 0.2149 0.1279 0.2489
#  0.089  0.1894 0.1577 0.1333 0.1167 0.0611 0.0824 0.1505 0.0944 0.1306
#  0.1845 0.1527 0.0967 0.1952 0.2565 0.1047 0.1942 0.288  0.086  0.234
#  0.1409 0.171  0.1049 0.1649 0.1599 0.1075 0.1655 0.1212 0.1007 0.1756
#  0.1198 0.1144 0.2313 0.0739 0.2677 0.0662 0.3017 0.1344 0.2291 0.1922
#  0.2118 0.0958 0.0734 0.1072 0.2167 0.0859 0.1148 0.222  0.2    0.0917
#  0.0799 0.1862 0.1274 0.0619 0.1298 0.1    0.0991 0.1366 0.2969 0.1464
#  0.263  0.0788 0.0949 0.1474 0.1559 0.1839 0.0726 0.2624 0.224  0.1677
#  0.1147 0.1311 0.1884 0.2049 0.1953 0.1261 0.1695 0.1892 0.1438 0.2099
#  0.0808 0.2599 0.0943 0.2235 0.1849 0.1273 0.1235 0.1992 0.0683 0.1629
#  0.258  0.0667 0.1335 0.1446 0.1431 0.2305 0.2274 0.0784 0.1924 0.0746
#  0.1588 0.1541 0.202  0.1646 0.1776 0.1114 0.1356 0.1016 0.0749 0.1106
#  0.1471 0.0791 0.118  0.2199 0.1659 0.173  0.247  0.225  0.2198 0.1714
#  0.1854 0.2534 0.1522 0.0624 0.1008 0.0689 0.1905 0.2529 0.2031 0.1249
#  0.1056 0.2557 0.2039 0.1904 0.1557 0.1452 0.1078 0.0607 0.3079 0.1259
#  0.0867 0.1041 0.2485 0.1019 0.1485 0.1239 0.2872 0.178  0.1403 0.0692
#  0.151  0.1972 0.1213 0.162  0.3065 0.139  0.1427 0.1186 0.0712 0.0963
#  0.1483 0.1353 0.1268 0.245  0.2788 0.1318 0.0759 0.1448 0.1037 0.1368
#  0.2549 0.1608 0.2197 0.0542 0.0608 0.3094 0.25   0.1323 0.0676 0.0729
#  0.2295 0.0617 0.0976 0.2699 0.192  0.1777 0.0796 0.2075 0.205  0.1347
#  0.06   0.1365 0.2727 0.21   0.098  0.2299 0.2408 0.2544 0.0668 0.1285
#  0.0603 0.1562 0.1059 0.1576 0.3075 0.182  0.2484 0.2363 0.1817 0.1166
#  0.1498 0.1348 0.1461 0.2328 0.2999 0.1948 0.2569 0.2588 0.1074 0.2583
#  0.1912 0.29   0.3074 0.1065 0.0925 0.1189 0.1689 0.2239 0.2509 0.2589
#  0.2343 0.2449 0.2582 0.1875 0.1891 0.2474 0.1205 0.0894 0.1122 0.3049
#  0.1482 0.1136 0.1749 0.0901 0.2869 0.1521 0.1682 0.1496 0.1242 0.1989
#  0.3089 0.3099 0.1305 0.1361 0.1879 0.1864 0.2332 0.0751 0.2799 0.2578
#  0.229  0.2148 0.1083 0.1632 0.138  0.1885 0.1288 0.2247 0.235  0.1624
#  0.2333 0.145  0.2528 0.2206 0.1969 0.2649 0.2115 0.231  0.1385 0.0768
#  0.1788 0.1607 0.1028 0.217  0.0654 0.0599 0.1581 0.1995 0.2814 0.2424
#  0.1039 0.1111 0.2025 0.1758 0.227  0.1472 0.2888 0.1392 0.2996 0.2749
#  0.2818 0.1316 0.1997 0.2731 0.1743 0.2657 0.0932 0.1253 0.08   0.1222
#  0.16   0.1966 0.1025 0.183  0.2483 0.1991 0.1071 0.1103 0.1036 0.0832
#  0.1982 0.2062 0.2383 0.0964 0.203  0.1568 0.1493 0.2581 0.2899 0.1793
#  0.0743 0.1112 0.208  0.152  0.1751 0.1038 0.1565 0.2211 0.216  0.1523
#  0.1941 0.1533 0.1435 0.1426 0.0714 0.2779 0.0996 0.2606 0.0888 0.1375
#  0.1726 0.0774 0.1663 0.1223 0.1221 0.1459 0.1595 0.1628 0.0579 0.0962
#  0.167  0.2614 0.1558 0.237  0.1525 0.1355 0.1417 0.1095 0.1343 0.2053
#  0.2734 0.1929 0.1292 0.2511 0.1422 0.1669 0.1501 0.1287 0.2897 0.2376
#  0.1357 0.1484 0.157  0.1322 0.0988 0.1372 0.2128 0.1183 0.1979 0.1645
#  0.2278 0.1596 0.1807 0.0691 0.1425 0.1191 0.1062 0.1635 0.1766 0.087
#  0.1867 0.1379 0.1128 0.2849 0.1861 0.1387 0.1411 0.1284 0.2011 0.2433
#  0.1491 0.0945 0.1739 0.2834 0.2248 0.1362 0.2455 0.1704 0.1913 0.0907
#  0.1513 0.1611 0.1916 0.1096 0.0705 0.1204 0.1442 0.2895 0.2077 0.2136
#  0.2967 0.1778 0.0766 0.289  0.0737 0.1218 0.1158 0.1126 0.1241 0.1551
#  0.242  0.133  0.1706 0.074  0.1696 0.2867 0.1412 0.1197 0.179  0.1454
#  0.1051 0.0807 0.128  0.1154 0.1312 0.2892 0.209  0.1843 0.2003 0.1479
#  0.1178 0.1528 0.1537 0.1791 0.1671 0.092  0.1809 0.0933 0.1304 0.2174
#  0.1545 0.2285 0.1217 0.1703 0.1146 0.2391 0.1529 0.1886 0.1141 0.1336
#  0.1286 0.1254 0.1734 0.1475 0.1014 0.2016 0.2052 0.2935 0.204  0.2326
#  0.1488 0.2127 0.1324 0.1936 0.2085 0.1159 0.1853 0.0863 0.2159 0.0775
#  0.1583 0.2048 0.1418 0.102  0.2322 0.1209 0.1974 0.1804 0.1821 0.1507
#  0.1317 0.1538 0.1272 0.2164 0.1462 0.1134 0.2086 0.1829 0.1236 0.1741
#  0.2352 0.1109 0.097  0.1615 0.1722 0.1754 0.1878 0.1467 0.1393 0.2017
#  0.0983 0.0742 0.1001 0.0951 0.147  0.0938 0.1163 0.1443 0.2294 0.2069
#  0.2452 0.1116 0.1046 0.2121 0.1384 0.175  0.2114 0.2476 0.1836 0.1715
#     nan 0.1267 0.2705 0.1665 0.1939 0.2262 0.244  0.2122 0.1457 0.1728
#  0.2359 0.1428 0.1633 0.1746]
# 대출 금액 데이터 타입 및 값: float64 [ 6000. 35000. 23200. ...   550.   850.   750.]
# 월 상환액 데이터 타입 및 값: float64 [ 187.94  822.95  680.82 ... 1090.59  811.54  900.96]
# 대출 기간 결측치 개수: 1
# 이자율 결측치 개수: 1
# 대출 금액 결측치 개수: 1
# 월 상환액 결측치 개수: 1
#      대출 금액     이자율  대출 기간   월 상환액   계산된 월 상환액        차이
# 0   6000.0  0.0797   36.0  187.94  187.935166  0.004834
# 1  35000.0  0.1447   60.0  822.95  822.942174  0.007826
# 2  23200.0  0.2499   60.0  680.82  680.814696  0.005304
# 3   4500.0  0.0993   36.0  145.06  145.054497  0.005503
# 4  15000.0  0.1640   36.0  530.33  530.322494  0.007506
# 차이가 큰 상위 5개:
#  1357049    217.786712
# 1215801    121.113810
# 141265     119.711189
# 714887     106.595954
# 1189692    100.431946
# Name: 차이, dtype: float64
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/3382510665.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['계산된 월 상환액'] = data.apply(calculate_monthly_payment, axis=1)
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/3382510665.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['차이'] = data['월 상환액'] - data['계산된 월 상환액']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 히스토그램과 KDE 그래프 그리기
plt.figure(figsize=(10, 6))

# 히스토그램
sns.histplot(data['차이'], kde=True, bins=30)

# 그래프 제목 및 라벨
plt.title('실제 월 상환액과 이론적 월 상환액 간의 차이 분포', fontsize=15)
plt.xlabel('차이', fontsize=12)
plt.ylabel('빈도수', fontsize=12)

# 그래프 보여주기
plt.show()
# Out:
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# '차이' 열의 통계적 정보 확인
difference_stats = data['차이'].describe()

# 결과 출력
print(difference_stats)
# Out:
# count    1.755294e+06
# mean    -3.597873e-03
# std      1.702714e+00
# min     -9.071711e+02
# 25%      2.475308e-03
# 50%      4.991562e-03
# 75%      7.492969e-03
# max      2.177867e+02
# Name: 차이, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# '차이'의 절대값 열 추가
data['차이 절대값'] = data['차이'].abs()

# 1. '차이'가 양수인 경우, 절대값이 큰 순서로 정렬 (상위 100개로 확장)
positive_diff_large = data[data['차이'] > 0].sort_values(by='차이 절대값', ascending=False).head(100)

# 2. '차이'가 음수인 경우, 절대값이 큰 순서로 정렬 (상위 100개로 확장)
negative_diff_large = data[data['차이'] < 0].sort_values(by='차이 절대값', ascending=False).head(100)

# 3. '차이'가 양수인 경우의 loan_status 분포
positive_loan_status_large = positive_diff_large['대출 상태'].value_counts()

# 4. '차이'가 음수인 경우의 loan_status 분포
negative_loan_status_large = negative_diff_large['대출 상태'].value_counts()

# 5. 원형 그래프로 시각화 (양수인 경우)
plt.figure(figsize=(8, 8))
plt.pie(positive_loan_status_large, labels=positive_loan_status_large.index, autopct='%1.1f%%', startangle=90)
plt.title('차이가 양수인 경우의 대출 상태 분포 (상위 100개)', fontsize=15)
plt.show()

# 6. 원형 그래프로 시각화 (음수인 경우)
plt.figure(figsize=(8, 8))
plt.pie(negative_loan_status_large, labels=negative_loan_status_large.index, autopct='%1.1f%%', startangle=90)
plt.title('차이가 음수인 경우의 대출 상태 분포 (상위 100개)', fontsize=15)
plt.show()
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/1641526332.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['차이 절대값'] = data['차이'].abs()

# %%
import pandas as pd

# 모기지 계좌 수 열 확인
mortgage_df = data[['모기지 계좌 수']]  # '모기지 계좌 수'만 추출

# 모기지 계좌 수에 대한 기본적인 통계 정보
mortgage_stats = mortgage_df['모기지 계좌 수'].describe()

# 모기지 계좌 수의 분포 확인
mortgage_dist = mortgage_df['모기지 계좌 수'].value_counts().sort_index()

# 결과 출력
print("모기지 계좌 수에 대한 통계 정보:\n", mortgage_stats)
print("\n모기지 계좌 수 분포:\n", mortgage_dist)
# Out:
# 모기지 계좌 수에 대한 통계 정보:
#  count    1.725310e+06
# mean     1.511964e+00
# std      1.870586e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      9.400000e+01
# Name: 모기지 계좌 수, dtype: float64
#
# 모기지 계좌 수 분포:
#  모기지 계좌 수
# 0.0     740062
# 1.0     304923
# 2.0     256230
# 3.0     178556
# 4.0     113294
# 5.0      64142
# 6.0      34123
# 7.0      16930
# 8.0       8203
# 9.0       4037
# 10.0      2105
# 11.0      1094
# 12.0       567
# 13.0       332
# 14.0       240
# 15.0       125
# 16.0        96
# 17.0        63
# 18.0        42
# 19.0        26
# 20.0        20
# 21.0        14
# 22.0        13
# 23.0        14
# 24.0        13
# 25.0         9
# 26.0         1
# 27.0         5
# 28.0         4
# 29.0         3
# 30.0         3
# 31.0         3
# 32.0         3
# 33.0         2
# 34.0         1
# 35.0         2
# 36.0         1
# 37.0         2
# 41.0         1
# 45.0         1
# 46.0         1
# 47.0         1
# 51.0         1
# 87.0         1
# 94.0         1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 모기지 계좌 수 분포 시각화 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(data['모기지 계좌 수'], bins=20, kde=False)

# 그래프 제목 및 라벨 설정
plt.title('모기지 계좌 수 분포', fontsize=16)
plt.xlabel('모기지 계좌 수', fontsize=12)
plt.ylabel('빈도수', fontsize=12)

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# '대출 상태'를 '양호'와 'Default'로 매핑
status_mapping = {
    'Fully Paid': '양호',
    'Charged Off': 'Default'
}

# '대출 상태'를 기준으로 '대출 상태 그룹'에 값을 매핑
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 'Current', 'Late', 'In Grace Period' 상태를 제거한 데이터 필터링
filtered_data = data[data['대출 상태 그룹'].notnull()]

# 부도 상태를 숫자로 매핑 ('양호' = 0, 'Default' = 1)
status_numeric_mapping = {'양호': 0, 'Default': 1}
filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)

# 모기지 계좌 수와 대출 상태 그룹만을 남겨서 결측값 제거
final_filtered_data = filtered_data[['모기지 계좌 수', '대출 상태 그룹']].dropna()

# 상관관계 계산
correlation = final_filtered_data.corr()

# 상관관계 출력
print("모기지 계좌 수와 대출 상태 간의 상관관계 (양호 vs Default):\n", correlation)

# 상관관계 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('모기지 계좌 수와 대출 상태 간의 상관관계 (양호 vs Default)')
plt.show()
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/1135751372.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)
# 모기지 계좌 수와 대출 상태 간의 상관관계 (양호 vs Default):
#            모기지 계좌 수  대출 상태 그룹
# 모기지 계좌 수  1.000000 -0.074586
# 대출 상태 그룹 -0.074586  1.000000
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/1135751372.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['대출 상태 그룹'] = filtered_data['대출 상태 그룹'].map(status_numeric_mapping)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 데이터프레임의 열 이름을 한 줄씩 출력
for col in data.columns:
    print(col)
# Out:
# 고유 ID
# 대출 신청 금액
# 대출 금액
# 투자자별 대출 금액
# 대출 기간
# 이자율
# 월 상환액
# 등급
# 하위 등급
# 직업명
# 근무 기간 (년)
# 주택 소유 상태
# 연간 소득
# 소득 검증 상태
# 발행일
# 대출 상태
# 상환 계획 여부
# url
# 대출 목적
# 대출 제목
# 우편번호
# 주소 상태
# 부채 대비 소득 비율
# 지난 2년간 30일 이상 연체된 계좌 수
# 최초 신용 계좌 개설일
# FICO 하한선
# FICO 상한선
# 지난 6개월간 조회 수
# 최근 연체 후 경과 개월 수
# 최근 기록 후 경과 개월 수
# 현재 활성 신용 계좌 수
# 공공 기록 수
# 회전 신용 잔액
# 회전 계좌 사용 비율
# 총 계좌 수
# 초기 상장 상태
# 잔여 원금
# 투자자별 잔여 원금
# 총 지급 금액
# 투자자별 총 지급 금액
# 지급된 원금 총액
# 지급된 이자 총액
# 지급된 연체 수수료 총액
# 차감 후 회수 금액
# 차감 후 회수 수수료
# 최근 지급일
# 최근 지급된 금액
# 다음 예정 상환일
# 최근 신용 조회일
# 최근 FICO 상한선
# 최근 FICO 하한선
# 지난 12개월간 (의료 제외) 추심 횟수
# 최근 90일 이상 연체 후 경과 개월 수
# 정책 코드
# 신청 유형
# 연간 공동 소득
# 공동 신청인의 부채 대비 소득 비율
# verification_status_joint
# 현재 연체 계좌 수
# 총 추심 금액
# 총 현재 잔액
# 지난 6개월간 활성 신용 계좌 수
# 활성 할부 계좌 수
# 지난 12개월간 할부 계좌 개설 수
# 지난 24개월간 할부 계좌 개설 수
# 최근 할부 계좌 개설 후 개월 수
# 할부 계좌 총 잔액
# 할부 계좌 한도 대비 사용 비율
# 지난 12개월간 회전 계좌 개설 수
# 지난 24개월간 회전 계좌 개설 수
# 최대 은행카드 잔액
# 모든 거래의 잔액 대비 한도 비율
# 회전 신용 고한도 총액
# 금융 조회 수
# 금융 거래 계좌 수
# 지난 12개월간 조회 수
# 최근 24개월간 개설된 계좌 수
# 평균 현재 잔액
# 은행카드 사용 가능 금액
# 은행카드 한도 대비 사용 비율
# 지난 12개월간 차감 횟수
# 현재 연체된 계좌의 연체 금액
# 가장 오래된 할부 계좌 개설 후 월 수
# 가장 오래된 회전 계좌 개설 후 월 수
# 최근 회전 계좌 개설 후 월 수
# 최근 계좌 개설 후 월 수
# 모기지 계좌 수
# 최근 은행카드 계좌 개설 후 개월 수
# 최근 은행카드 연체 후 개월 수
# 최근 조회 후 개월 수
# 최근 회전 계좌 연체 후 개월 수
# 120일 이상 연체된 계좌 수
# 활성 은행카드 계좌 수
# 활성 회전 계좌 수
# 만족스러운 은행카드 계좌 수
# 은행카드 계좌 수
# 할부 계좌 수
# 활성 회전 계좌 수
# 회전 계좌 수
# 잔액이 0보다 큰 회전 계좌 수
# 만족스러운 계좌 수
# 최근 2개월간 120일 이상 연체된 계좌 수
# 현재 30일 이상 연체된 계좌 수
# 최근 24개월간 90일 이상 연체된 계좌 수
# 지난 12개월간 개설된 계좌 수
# 연체 경험이 없는 거래 비율
# 한도 75% 초과 은행카드 계좌 비율
# 공공 기록 파산 수
# 세금 유치권 수
# 총 고신용 한도
# 모기지 제외 총 잔액
# 총 은행카드 한도
# 총 할부 계좌 고신용 한도
# 공동 대출자의 회전 신용 잔액
# 부차 신청자 FICO 하한선
# 부차 신청자 FICO 상한선
# 부차 신청자 최초 신용 계좌 개설일
# 부차 신청자 최근 6개월간 조회 수
# 부차 신청자 모기지 계좌 수
# 부차 신청자 활성 계좌 수
# 부차 신청자 회전 신용 한도 대비 사용 비율
# 부차 신청자 활성 할부 계좌 수
# 부차 신청자 회전 계좌 수
# 부차 신청자 지난 12개월간 차감 횟수
# 부차 신청자 지난 12개월간 (의료 제외) 추심 횟수
# 고난 계획 여부
# 고난 계획 유형
# 고난 계획 이유
# 고난 계획 상태
# 고난 기간
# 고난 기간 동안의 이자 지급 금액
# 고난 계획 시작일
# 고난 계획 종료일
# 상환 계획 시작일
# 고난 계획 기간
# 고난 계획 시작일 기준 연체 일수
# 고난 계획 시작일 기준 대출 상태
# 고난 계획 시작일 기준 예상 추가 이자
# 고난 계획 시작일 기준 상환 잔액
# 고난 계획 시작일 기준 최근 지급 금액
# 채무 조정 여부
# 대출 상태 그룹
# 이자율 구간
# 신용등급
# 계산된 월 상환액
# 차이
# 차이 절대값

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 대출 상태를 '양호'와 'Default'로 매핑
status_mapping = {
    'Fully Paid': 0,  # 양호
    'Charged Off': 1  # Default
}

# '대출 상태'를 기준으로 '대출 상태 그룹'에 값을 매핑
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# 상관관계 분석에 사용할 변수 목록 (모기지 계좌 수 제외)
variables_of_interest = [
    '현재 활성 신용 계좌 수', '총 계좌 수', '할부 계좌 수',
    '회전 계좌 수', '지난 6개월간 조회 수', '지난 2년간 30일 이상 연체된 계좌 수',
    '최근 연체 후 경과 개월 수', '회전 신용 잔액', '연간 소득'
]

# 분석할 데이터 필터링 (결측치 제거)
filtered_data = data[['대출 상태 그룹'] + variables_of_interest].dropna()

# 상관관계 계산
correlation_matrix = filtered_data.corr()

# 상관관계 히트맵 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('대출 상태와 기존 대출 관련 변수 간 상관관계', fontsize=16)
plt.show()
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/3963622581.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 대출 목적의 분포 확인
purpose_counts = data['대출 목적'].value_counts()

# 대출 목적의 분포 시각화 (막대 그래프)
plt.figure(figsize=(10, 6))
sns.barplot(x=purpose_counts.index, y=purpose_counts.values)
plt.title('대출 목적별 대출 건수', fontsize=16)
plt.xlabel('대출 목적', fontsize=12)
plt.ylabel('대출 건수', fontsize=12)
plt.xticks(rotation=90)  # x축 레이블을 90도로 회전
plt.show()

# %%
# 대출 신청 유형의 분포 확인
application_type_counts = data['신청 유형'].value_counts()

# 대출 신청 유형의 분포 시각화 (막대 그래프)
plt.figure(figsize=(6, 4))
sns.barplot(x=application_type_counts.index, y=application_type_counts.values)
plt.title('대출 신청 유형별 대출 건수', fontsize=16)
plt.xlabel('대출 신청 유형', fontsize=12)
plt.ylabel('대출 건수', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# 대출 목적 상위 10개 추출
top_10_purpose = data['대출 목적'].value_counts().head(10)

# 상위 10개 대출 목적과 갯수 출력
print("대출 목적 상위 10개:\n", top_10_purpose)
# Out:
# 대출 목적 상위 10개:
#  대출 목적
# debt_consolidation    983049
# credit_card           417587
# home_improvement      115582
# other                 106217
# major_purchase         37713
# medical                21153
# small_business         18015
# car                    17822
# vacation               12143
# house                  11822
# Name: count, dtype: int64

# %% [markdown]
# ### 아 모르겠다 일단 부채대비소득비율부터 봐봐

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 대출 상태를 '양호'와 '부도'로 매핑
status_mapping = {
    'Fully Paid': '양호',
    'Charged Off': '부도',
    'Default': '부도'
}

# 대출 상태 매핑 적용
data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# '양호'와 '부도' 그룹의 DTI 분포를 박스플롯으로 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x='대출 상태 그룹', y='부채 대비 소득 비율', data=data)
plt.title('DTI와 대출 상태 간의 관계', fontsize=16)
plt.xlabel('대출 상태 그룹', fontsize=12)
plt.ylabel('부채 대비 소득 비율 (DTI)', fontsize=12)
plt.show()
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/3333800434.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['대출 상태 그룹'] = data['대출 상태'].map(status_mapping)

# %%
# IQR 계산을 통한 이상치 제거 함수
def remove_outliers_iqr(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # IQR 범위 내에 있는 데이터만 필터링
    filtered_df = dataframe[(dataframe[column] >= lower_bound) & (dataframe[column] <= upper_bound)]
    return filtered_df

# '부채 대비 소득 비율' 컬럼에서 이상치를 제거
filtered_data = remove_outliers_iqr(data, '부채 대비 소득 비율')

# 이상치 제거 후 박스플롯 시각화
plt.figure(figsize=(10, 6))
sns.boxplot(x='대출 상태 그룹', y='부채 대비 소득 비율', data=filtered_data)
plt.title('DTI와 대출 상태 간의 관계 (이상치 제거 후)', fontsize=16)
plt.xlabel('대출 상태 그룹', fontsize=12)
plt.ylabel('부채 대비 소득 비율 (DTI)', fontsize=12)
plt.show()

# %%
# DTI 분포를 히스토그램으로 시각화
plt.figure(figsize=(10, 6))
sns.histplot(data['부채 대비 소득 비율'], bins=50, kde=True)
plt.title('DTI 분포', fontsize=16)
plt.xlabel('부채 대비 소득 비율 (DTI)', fontsize=12)
plt.ylabel('빈도수', fontsize=12)
plt.show()

# %%
# DTI와 대출 금액 간의 상관관계 계산
correlation = data[['부채 대비 소득 비율', '대출 금액']].corr()

# 상관관계 출력
print('DTI와 대출 금액 간의 상관관계:')
print(correlation)

# DTI와 대출 금액 간의 관계를 산점도로 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x='부채 대비 소득 비율', y='대출 금액', data=data)
plt.title('DTI와 대출 금액 간의 상관관계', fontsize=16)
plt.xlabel('부채 대비 소득 비율 (DTI)', fontsize=12)
plt.ylabel('대출 금액', fontsize=12)
plt.show()
# Out:
# DTI와 대출 금액 간의 상관관계:
#              부채 대비 소득 비율     대출 금액
# 부채 대비 소득 비율     1.000000  0.053877
# 대출 금액           0.053877  1.000000

# %% [markdown]
# # 머신러닝 해야되니까 범주형 데이터를 숫자형으로 변환해보자.

# %%
from sklearn.preprocessing import LabelEncoder

# 데이터프레임에서 범주형 변수만 선택
categorical_columns = data.select_dtypes(include=['object']).columns

# 이미 숫자형으로 변환된 컬럼들을 제외한 범주형 변수들만 변환
exclude_columns = [
    '고유 ID', '대출 기간', '이자율', '회전 계좌 사용 비율', '근무 기간 (년)', '발행일', '최근 지급일', '다음 예정 상환일',
    '최근 신용 조회일', '최근 기록 후 경과 개월 수', '최근 90일 이상 연체 후 경과 개월 수', '부차 신청자 최초 신용 계좌 개설일'
]

# 변환할 컬럼 목록 생성 (제외해야 할 컬럼은 제외)
columns_to_encode = [col for col in categorical_columns if col not in exclude_columns]

# 각 컬럼에 대해 레이블 인코딩 진행
for col in columns_to_encode:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))

# 결과 확인 (변환된 데이터 일부 출력)
print(data[columns_to_encode].head())
# Out:
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))
#    등급  하위 등급     직업명  주택 소유 상태  소득 검증 상태  대출 상태  상환 계획 여부      url  대출 목적  \
# 0   0      4  324247         1         2      5         0   235128      2
# 1   2     11  242959         5         1      1         0   478975      1
# 2   4     23  243403         1         2      0         0  1577691      2
# 3   1      6  216223         1         0      1         0   260258      4
# 4   2     13  279182         1         2      1         0   645883      2
#
#    대출 제목  우편번호  주소 상태  최초 신용 계좌 개설일  초기 상장 상태  신청 유형  \
# 0  10743   528     23           742         1      1
# 1   8391    77     31           169         1      0
# 2  10743   692     36           544         0      0
# 3  16480   328      9           610         1      0
# 4  10743   269     27           174         1      1
#
#    verification_status_joint  고난 계획 여부  고난 계획 유형  고난 계획 이유  고난 계획 상태  \
# 0                          2         0         9        17         4
# 1                          3         0         9        17         4
# 2                          3         0         9        17         4
# 3                          3         0         9        17         4
# 4                          2         1         1        14         0
#
#    고난 계획 시작일  고난 계획 종료일  상환 계획 시작일  고난 계획 시작일 기준 대출 상태  채무 조정 여부  대출 상태 그룹
# 0         46         47         46                  13         0         2
# 1         46         47         46                  13         0         0
# 2         46         47         46                  13         1         1
# 3         46         47         46                  13         0         0
# 4         34         22         33                   0         0         0
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/2236367984.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))

# %% [markdown]
# ## 일단 결측치들 다 쳐내자

# %%
# 결측치 확인
import pandas as pd

# 데이터프레임의 결측치 개수와 비율 확인
missing_data = data.isnull().sum().sort_values(ascending=False)
missing_percentage = (data.isnull().sum() / data.shape[0]).sort_values(ascending=False) * 100

# 결측치 개수와 비율을 하나의 데이터프레임으로 병합
missing_info = pd.DataFrame({
    'Missing Count': missing_data,
    'Percentage': missing_percentage
})

# 결측치가 있는 상위 10개의 컬럼 확인
missing_info.head(10)
# Out:
#                           Missing Count  Percentage
# 고난 계획 시작일 기준 연체 일수              1669259   95.098542
# 고난 계획 기간                        1669258   95.098485
# 고난 기간                           1669258   95.098485
# 고난 계획 시작일 기준 예상 추가 이자           1647814   93.876809
# 고난 기간 동안의 이자 지급 금액              1646163   93.782751
# 고난 계획 시작일 기준 최근 지급 금액           1646163   93.782751
# 고난 계획 시작일 기준 상환 잔액              1646163   93.782751
# 부차 신청자 회전 신용 한도 대비 사용 비율        1638552   93.349148
# 부차 신청자 지난 12개월간 차감 횟수           1636589   93.237315
# 부차 신청자 회전 계좌 수                  1636589   93.237315

# %%
# 결측치 확인
import pandas as pd

# 데이터프레임의 결측치 개수와 비율 확인
missing_data = data.isnull().sum().sort_values(ascending=False)
missing_percentage = (data.isnull().sum() / data.shape[0]).sort_values(ascending=False) * 100

# 결측치 개수와 비율을 하나의 데이터프레임으로 병합
missing_info = pd.DataFrame({
    'Missing Count': missing_data,
    'Percentage': missing_percentage
})

# 결측치가 있는 상위 10개의 컬럼 확인
missing_info.head(10)
# Out:
#                           Missing Count  Percentage
# 고난 계획 시작일 기준 연체 일수              1669259   95.098542
# 고난 계획 기간                        1669258   95.098485
# 고난 기간                           1669258   95.098485
# 고난 계획 시작일 기준 예상 추가 이자           1647814   93.876809
# 고난 기간 동안의 이자 지급 금액              1646163   93.782751
# 고난 계획 시작일 기준 최근 지급 금액           1646163   93.782751
# 고난 계획 시작일 기준 상환 잔액              1646163   93.782751
# 부차 신청자 회전 신용 한도 대비 사용 비율        1638552   93.349148
# 부차 신청자 지난 12개월간 차감 횟수           1636589   93.237315
# 부차 신청자 회전 계좌 수                  1636589   93.237315

# %%
# 50% 이상의 결측치를 가진 열을 필터링
columns_to_drop = missing_info[missing_info['Percentage'] > 50].index

# 50% 이상의 결측치를 가진 열들 출력
print(f"결측치가 50% 이상인 열:\n{columns_to_drop.tolist()}")
# Out:
# 결측치가 50% 이상인 열:
# ['고난 계획 시작일 기준 연체 일수', '고난 계획 기간', '고난 기간', '고난 계획 시작일 기준 예상 추가 이자', '고난 기간 동안의 이자 지급 금액', '고난 계획 시작일 기준 최근 지급 금액', '고난 계획 시작일 기준 상환 잔액', '부차 신청자 회전 신용 한도 대비 사용 비율', '부차 신청자 지난 12개월간 차감 횟수', '부차 신청자 회전 계좌 수', '부차 신청자 활성 할부 계좌 수', '부차 신청자 활성 계좌 수', '부차 신청자 모기지 계좌 수', '부차 신청자 지난 12개월간 (의료 제외) 추심 횟수', '부차 신청자 최근 6개월간 조회 수', '부차 신청자 최초 신용 계좌 개설일', '부차 신청자 FICO 상한선', '부차 신청자 FICO 하한선', '공동 대출자의 회전 신용 잔액', '공동 신청인의 부채 대비 소득 비율', '연간 공동 소득', '최근 기록 후 경과 개월 수', '최근 은행카드 연체 후 개월 수', '최근 90일 이상 연체 후 경과 개월 수', '최근 회전 계좌 연체 후 개월 수', '다음 예정 상환일', '최근 연체 후 경과 개월 수']

# %%
# 50% 이상의 결측치를 가진 열 제거
data_cleaned = data.drop(columns=columns_to_drop)

# 제거된 후의 데이터프레임 확인
print(f"\n제거된 후의 데이터프레임 형태: {data_cleaned.shape}")
# Out:
# 제거된 후의 데이터프레임 형태: (1755294, 120)

# %%
# 결측치가 있는 열과 그 개수 구하기
missing = data.isnull().sum()
missing = missing[missing > 0]  # 결측치가 있는 열만 필터링
missing.sort_values(ascending=False, inplace=True)  # 결측치 개수가 많은 순으로 정렬

# 그래프 그리기
plt.figure(figsize=(15, 5))
plt.bar(missing.index, missing.values)
plt.xlabel("Features", fontsize=15)
plt.ylabel("Number of missing values", fontsize=15)
plt.title("Number of missing data by feature", fontsize=15)
plt.xticks(rotation=90)  # x축 레이블을 90도로 회전

# 그래프 출력
plt.show()

# %%
# 각 열의 결측치 개수와 결측치 비율을 계산하여 데이터프레임으로 표시
missing_data = data.isnull().sum()  # 각 열의 결측치 개수 계산
missing_percentage = (data.isnull().sum() / len(data)) * 100  # 각 열의 결측치 비율 계산

# 데이터프레임으로 정리
missing_df = pd.DataFrame({
    'Missing Count': missing_data,
    'Missing Percentage': missing_percentage
})

# 결측치 개수가 0인 열은 제외
missing_df = missing_df[missing_df['Missing Count'] > 0]

# 결측치 개수가 많은 순으로 정렬
missing_df.sort_values(by='Missing Count', ascending=False, inplace=True)

# 결과 출력
missing_df.reset_index(inplace=True)
missing_df.rename(columns={'index': 'Feature'}, inplace=True)

# 데이터프레임 결과를 출력
missing_df
# Out:
#                           Feature  Missing Count  Missing Percentage
# 0              고난 계획 시작일 기준 연체 일수        1669259           95.098542
# 1                        고난 계획 기간        1669258           95.098485
# 2                           고난 기간        1669258           95.098485
# 3           고난 계획 시작일 기준 예상 추가 이자        1647814           93.876809
# 4           고난 계획 시작일 기준 최근 지급 금액        1646163           93.782751
# 5              고난 계획 시작일 기준 상환 잔액        1646163           93.782751
# 6              고난 기간 동안의 이자 지급 금액        1646163           93.782751
# 7        부차 신청자 회전 신용 한도 대비 사용 비율        1638552           93.349148
# 8               부차 신청자 활성 할부 계좌 수        1636589           93.237315
# 9                 부차 신청자 FICO 하한선        1636589           93.237315
# 10                부차 신청자 FICO 상한선        1636589           93.237315
# 11            부차 신청자 최초 신용 계좌 개설일        1636589           93.237315
# 12            부차 신청자 최근 6개월간 조회 수        1636589           93.237315
# 13                부차 신청자 모기지 계좌 수        1636589           93.237315
# 14                 부차 신청자 활성 계좌 수        1636589           93.237315
# 15               공동 대출자의 회전 신용 잔액        1636589           93.237315
# 16          부차 신청자 지난 12개월간 차감 횟수        1636589           93.237315
# 17                 부차 신청자 회전 계좌 수        1636589           93.237315
# 18  부차 신청자 지난 12개월간 (의료 제외) 추심 횟수        1636589           93.237315
# 19            공동 신청인의 부채 대비 소득 비율        1628939           92.801491
# 20                       연간 공동 소득        1628937           92.801377
# 21                최근 기록 후 경과 개월 수        1498706           85.382050
# 22              최근 은행카드 연체 후 개월 수        1365588           77.798249
# 23         최근 90일 이상 연체 후 경과 개월 수        1321877           75.308011
# 24             최근 회전 계좌 연체 후 개월 수        1197240           68.207377
# 25                      다음 예정 상환일        1115888           63.572712
# 26                최근 연체 후 경과 개월 수         922198           52.538093
# 27              할부 계좌 한도 대비 사용 비율         694479           39.564825
# 28             최근 할부 계좌 개설 후 개월 수         556000           31.675605
# 29             모든 거래의 잔액 대비 한도 비율         519945           29.621533
# 30                        금융 조회 수         519720           29.608715
# 31                  지난 12개월간 조회 수         519720           29.608715
# 32                     금융 거래 계좌 수         519720           29.608715
# 33             지난 6개월간 활성 신용 계좌 수         519720           29.608715
# 34                     활성 할부 계좌 수         519720           29.608715
# 35                     최대 은행카드 잔액         519720           29.608715
# 36            지난 12개월간 회전 계좌 개설 수         519720           29.608715
# 37                     할부 계좌 총 잔액         519720           29.608715
# 38            지난 24개월간 할부 계좌 개설 수         519720           29.608715
# 39            지난 12개월간 할부 계좌 개설 수         519720           29.608715
# 40            지난 24개월간 회전 계좌 개설 수         519720           29.608715
# 41                   최근 조회 후 개월 수         222766           12.691093
# 42                      근무 기간 (년)         123084            7.012159
# 43       최근 2개월간 120일 이상 연체된 계좌 수          96750            5.511897
# 44          가장 오래된 할부 계좌 개설 후 월 수          93245            5.312216
# 45               은행카드 한도 대비 사용 비율          50389            2.870687
# 46           한도 75% 초과 은행카드 계좌 비율          49830            2.838841
# 47                  은행카드 사용 가능 금액          49536            2.822091
# 48           최근 은행카드 계좌 개설 후 개월 수          48370            2.755664
# 49                연체 경험이 없는 거래 비율          42188            2.403472
# 50                       평균 현재 잔액          42162            2.401991
# 51          가장 오래된 회전 계좌 개설 후 월 수          42088            2.397775
# 52                        회전 계좌 수          42088            2.397775
# 53              최근 회전 계좌 개설 후 월 수          42088            2.397775
# 54       최근 24개월간 90일 이상 연체된 계좌 수          42087            2.397718
# 55                      은행카드 계좌 수          42087            2.397718
# 56                        총 추심 금액          42087            2.397718
# 57                       총 고신용 한도          42087            2.397718
# 58                        총 현재 잔액          42087            2.397718
# 59                   회전 신용 고한도 총액          42087            2.397718
# 60                 최근 계좌 개설 후 월 수          42087            2.397718
# 61                 총 할부 계좌 고신용 한도          42087            2.397718
# 62              지난 12개월간 개설된 계좌 수          42087            2.397718
# 63                     활성 회전 계좌 수          42087            2.397718
# 64             현재 30일 이상 연체된 계좌 수          42087            2.397718
# 65               120일 이상 연체된 계좌 수          42087            2.397718
# 66              잔액이 0보다 큰 회전 계좌 수          42087            2.397718
# 67                   활성 은행카드 계좌 수          42087            2.397718
# 68                     활성 회전 계좌 수          42087            2.397718
# 69                        할부 계좌 수          42087            2.397718
# 70                     만족스러운 계좌 수          35112            2.000349
# 71                만족스러운 은행카드 계좌 수          35112            2.000349
# 72                       모기지 계좌 수          29984            1.708204
# 73                      총 은행카드 한도          29984            1.708204
# 74              최근 24개월간 개설된 계좌 수          29984            1.708204
# 75                    모기지 제외 총 잔액          29984            1.708204
# 76                         이자율 구간           5358            0.305248
# 77                         최근 지급일           3029            0.172564
# 78                    부채 대비 소득 비율           1861            0.106022
# 79                    회전 계좌 사용 비율           1587            0.090412
# 80                     공공 기록 파산 수            851            0.048482
# 81                 지난 12개월간 차감 횟수             94            0.005355
# 82         지난 12개월간 (의료 제외) 추심 횟수             94            0.005355
# 83                       세금 유치권 수             72            0.004102
# 84                      최근 신용 조회일             41            0.002336
# 85               현재 연체된 계좌의 연체 금액             16            0.000912
# 86                     현재 연체 계좌 수             16            0.000912
# 87                         총 계좌 수             16            0.000912
# 88                        공공 기록 수             16            0.000912
# 89                  현재 활성 신용 계좌 수             16            0.000912
# 90                   지난 6개월간 조회 수             16            0.000912
# 91         지난 2년간 30일 이상 연체된 계좌 수             16            0.000912
# 92                          연간 소득              2            0.000114

# %% [markdown]
# ## 50% 이하 쳐내!!

# %%
# 1. 데이터프레임의 초기 총 컬럼 수 확인
initial_column_count = data.shape[1]
print(f"초기 데이터프레임의 총 컬럼 수: {initial_column_count}")

# 2. 제거할 컬럼들이 실제 데이터프레임에 존재하는지 확인
actual_columns_to_drop = [col for col in columns_to_drop if col in data.columns]
print(f"제거할 실제 컬럼들: {actual_columns_to_drop}")

# 3. 실제 제거 과정 수행
data_cleaned = data.drop(columns=actual_columns_to_drop)

# 4. 제거 후의 총 컬럼 수 확인
final_column_count = data_cleaned.shape[1]
print(f"제거된 후의 데이터프레임 총 컬럼 수: {final_column_count}")

# 5. 제거 후 남아있는 컬럼 확인
remaining_columns = data_cleaned.columns.tolist()
print(f"남아있는 컬럼들: {remaining_columns}")
# Out:
# 초기 데이터프레임의 총 컬럼 수: 147
# 제거할 실제 컬럼들: ['고난 계획 시작일 기준 연체 일수', '고난 계획 기간', '고난 기간', '고난 계획 시작일 기준 예상 추가 이자', '고난 기간 동안의 이자 지급 금액', '고난 계획 시작일 기준 최근 지급 금액', '고난 계획 시작일 기준 상환 잔액', '부차 신청자 회전 신용 한도 대비 사용 비율', '부차 신청자 지난 12개월간 차감 횟수', '부차 신청자 회전 계좌 수', '부차 신청자 활성 할부 계좌 수', '부차 신청자 활성 계좌 수', '부차 신청자 모기지 계좌 수', '부차 신청자 지난 12개월간 (의료 제외) 추심 횟수', '부차 신청자 최근 6개월간 조회 수', '부차 신청자 최초 신용 계좌 개설일', '부차 신청자 FICO 상한선', '부차 신청자 FICO 하한선', '공동 대출자의 회전 신용 잔액', '공동 신청인의 부채 대비 소득 비율', '연간 공동 소득', '최근 기록 후 경과 개월 수', '최근 은행카드 연체 후 개월 수', '최근 90일 이상 연체 후 경과 개월 수', '최근 회전 계좌 연체 후 개월 수', '다음 예정 상환일', '최근 연체 후 경과 개월 수']
# 제거된 후의 데이터프레임 총 컬럼 수: 120
# 남아있는 컬럼들: ['고유 ID', '대출 신청 금액', '대출 금액', '투자자별 대출 금액', '대출 기간', '이자율', '월 상환액', '등급', '하위 등급', '직업명', '근무 기간 (년)', '주택 소유 상태', '연간 소득', '소득 검증 상태', '발행일', '대출 상태', '상환 계획 여부', 'url', '대출 목적', '대출 제목', '우편번호', '주소 상태', '부채 대비 소득 비율', '지난 2년간 30일 이상 연체된 계좌 수', '최초 신용 계좌 개설일', 'FICO 하한선', 'FICO 상한선', '지난 6개월간 조회 수', '현재 활성 신용 계좌 수', '공공 기록 수', '회전 신용 잔액', '회전 계좌 사용 비율', '총 계좌 수', '초기 상장 상태', '잔여 원금', '투자자별 잔여 원금', '총 지급 금액', '투자자별 총 지급 금액', '지급된 원금 총액', '지급된 이자 총액', '지급된 연체 수수료 총액', '차감 후 회수 금액', '차감 후 회수 수수료', '최근 지급일', '최근 지급된 금액', '최근 신용 조회일', '최근 FICO 상한선', '최근 FICO 하한선', '지난 12개월간 (의료 제외) 추심 횟수', '정책 코드', '신청 유형', 'verification_status_joint', '현재 연체 계좌 수', '총 추심 금액', '총 현재 잔액', '지난 6개월간 활성 신용 계좌 수', '활성 할부 계좌 수', '지난 12개월간 할부 계좌 개설 수', '지난 24개월간 할부 계좌 개설 수', '최근 할부 계좌 개설 후 개월 수', '할부 계좌 총 잔액', '할부 계좌 한도 대비 사용 비율', '지난 12개월간 회전 계좌 개설 수', '지난 24개월간 회전 계좌 개설 수', '최대 은행카드 잔액', '모든 거래의 잔액 대비 한도 비율', '회전 신용 고한도 총액', '금융 조회 수', '금융 거래 계좌 수', '지난 12개월간 조회 수', '최근 24개월간 개설된 계좌 수', '평균 현재 잔액', '은행카드 사용 가능 금액', '은행카드 한도 대비 사용 비율', '지난 12개월간 차감 횟수', '현재 연체된 계좌의 연체 금액', '가장 오래된 할부 계좌 개설 후 월 수', '가장 오래된 회전 계좌 개설 후 월 수', '최근 회전 계좌 개설 후 월 수', '최근 계좌 개설 후 월 수', '모기지 계좌 수', '최근 은행카드 계좌 개설 후 개월 수', '최근 조회 후 개월 수', '120일 이상 연체된 계좌 수', '활성 은행카드 계좌 수', '활성 회전 계좌 수', '만족스러운 은행카드 계좌 수', '은행카드 계좌 수', '할부 계좌 수', '활성 회전 계좌 수', '회전 계좌 수', '잔액이 0보다 큰 회전 계좌 수', '만족스러운 계좌 수', '최근 2개월간 120일 이상 연체된 계좌 수', '현재 30일 이상 연체된 계좌 수', '최근 24개월간 90일 이상 연체된 계좌 수', '지난 12개월간 개설된 계좌 수', '연체 경험이 없는 거래 비율', '한도 75% 초과 은행카드 계좌 비율', '공공 기록 파산 수', '세금 유치권 수', '총 고신용 한도', '모기지 제외 총 잔액', '총 은행카드 한도', '총 할부 계좌 고신용 한도', '고난 계획 여부', '고난 계획 유형', '고난 계획 이유', '고난 계획 상태', '고난 계획 시작일', '고난 계획 종료일', '상환 계획 시작일', '고난 계획 시작일 기준 대출 상태', '채무 조정 여부', '대출 상태 그룹', '이자율 구간', '신용등급', '계산된 월 상환액', '차이', '차이 절대값']

# %% [markdown]
# ## LableEncoder로 숫자형으로 다 바꿔보자

# %%
# Step 1: 모든 object 타입의 범주형 컬럼 찾기
categorical_columns = data.select_dtypes(include=['object']).columns

print(f"모든 범주형 컬럼: {categorical_columns.tolist()}")

# Step 2: LabelEncoder를 모든 범주형 변수에 적용
from sklearn.preprocessing import LabelEncoder

# 각 컬럼에 대해 LabelEncoder 적용
for col in categorical_columns:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리

# 결과 확인
print(f"인코딩이 완료된 데이터프레임의 정보:")
print(data.info())

# 타겟 변수 확인
print("대출 상태 그룹 값 분포:\n", data['대출 상태 그룹'].value_counts())
# Out:
# 모든 범주형 컬럼: ['고유 ID', '근무 기간 (년)', '발행일', '회전 계좌 사용 비율', '최근 지급일', '다음 예정 상환일', '최근 신용 조회일', '부차 신청자 최초 신용 계좌 개설일']
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리
# 인코딩이 완료된 데이터프레임의 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1755294 entries, 0 to 1755294
# Columns: 147 entries, 고유 ID to 차이 절대값
# dtypes: category(1), float64(112), int64(34)
# memory usage: 1.9 GB
# None
# 대출 상태 그룹 값 분포:
#  대출 상태 그룹
# 2    898522
# 0    639138
# 1    217634
# Name: count, dtype: int64
# /var/folders/r2/nm86hl8s7fv3n393n0wj8s700000gn/T/ipykernel_27331/368529242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = le.fit_transform(data[col].astype(str))  # 결측치가 있을 수 있으므로 문자열로 변환하여 처리

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Step 1: Feature와 Target 변수 분리
X = data.drop(columns=['대출 상태 그룹'])  # Target 변수를 제외한 나머지 모든 열을 Feature로 설정
y = data['대출 상태 그룹']  # Target 변수 설정

# Step 2: 학습 데이터와 테스트 데이터로 분리 (7:3 비율로 분리)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: StandardScaler를 사용하여 스케일링 (수치형 변수만 스케일링)
scaler = StandardScaler()

# X_train과 X_test의 모든 수치형 컬럼에 대해 스케일링 적용
numerical_columns = X.select_dtypes(include=['float64', 'int64']).columns
X_train[numerical_columns] = scaler.fit_transform(X_train[numerical_columns])
X_test[numerical_columns] = scaler.transform(X_test[numerical_columns])

# 데이터 분리 및 스케일링이 완료되었음을 확인
print("스케일링이 완료된 X_train과 X_test의 형태:")
print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
# Out:
# 스케일링이 완료된 X_train과 X_test의 형태:
# X_train: (1228705, 146), X_test: (526589, 146)

# %% [markdown]
# ### 왜 칼럼이 146개가 됐는가?
# 결측치를 제거한 이후에도 X_train과 X_test에 146개의 컬럼이 남아 있는 이유는, 우리가 결측치를 가진 컬럼만 제거했기 때문입니다. 이 과정에서, 원래 남아있던 컬럼들을 대상으로 한 후속 변환(범주형 인코딩 등)이 적용되면서, 새롭게 생성된 원-핫 인코딩 컬럼들이 추가된 것
#
# 그니까,
# 원-핫 인코딩이나 라벨 인코딩 시, 범주형 변수가 여러 개의 새로운 이진 변수로 분리
# 범주형 변수의 고유값 개수만큼 새로운 컬럼이 추가되기 때문에, 결과적으로 원래 컬럼 수보다 더 많은 컬럼이 생김
# 이렇게 추가된 컬럼 때문에 최종적으로 컬럼의 수가 결측치를 제거하기 전보다 많아지거나 유지될 수 있음!

# %%
# 대출 이후의 변수로 보이는 컬럼들 목록 (필요 시 추가/수정)
post_loan_columns = [
    '대출 상태', '상환 계획 여부', '최근 지급일', '최근 지급된 금액', '총 지급 금액',
    '투자자별 총 지급 금액', '지급된 원금 총액', '지급된 이자 총액', '지급된 연체 수수료 총액',
    '차감 후 회수 금액', '차감 후 회수 수수료', '잔여 원금', '투자자별 잔여 원금'
    # 필요시 추가: 대출 이후의 정보를 포함한 변수
]

# 대출 이전의 변수들만 포함하는 데이터프레임 생성
X_train = X_train.drop(columns=post_loan_columns, errors='ignore')
X_test = X_test.drop(columns=post_loan_columns, errors='ignore')

# 데이터셋의 차원 확인
print(f"대출 이후의 변수 제거 후 X_train 형태: {X_train.shape}, X_test 형태: {X_test.shape}")
# Out:
# 대출 이후의 변수 제거 후 X_train 형태: (1228705, 133), X_test 형태: (526589, 133)

# %%
# selected_features에 새로운 열 추가
selected_features = [
    # 대출 신청 관련 변수
    '대출 신청 금액', '대출 금액', '이자율', '대출 기간', '월 상환액',
    # 개인 정보 관련 변수
    '등급', '근무 기간 (년)', '주택 소유 상태', '연간 소득',
    # 신용 정보 관련 변수
    '부채 대비 소득 비율', 'FICO 하한선', 'FICO 상한선', '현재 활성 신용 계좌 수', '공공 기록 수',
    # 회전 신용 관련 변수
    '회전 신용 잔액', '회전 계좌 사용 비율', '총 계좌 수', '지난 6개월간 활성 신용 계좌 수',
    # 할부 계좌 관련 변수
    '활성 할부 계좌 수', '지난 12개월간 할부 계좌 개설 수', '최대 은행카드 잔액',
    # 추가된 변수
    '신청 유형', '대출 목적', '최초 신용 계좌 개설일', '회전 신용 고한도 총액',
    '현재 연체 계좌 수', '최근 연체 후 경과 개월 수'
]

# 수정된 selected_features를 이용하여 X_train과 X_test를 구성
X_train = X_train[selected_features].copy()
X_test = X_test[selected_features].copy()

# 데이터 타입과 결측치 여부 확인
print("X_train 데이터프레임의 정보:")
print(X_train.info())

print("\nX_test 데이터프레임의 정보:")
print(X_test.info())
# Out:
# X_train 데이터프레임의 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1228705 entries, 1650117 to 121958
# Data columns (total 27 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   대출 신청 금액             1228705 non-null  float64
#  1   대출 금액                1228705 non-null  float64
#  2   이자율                  1228705 non-null  float64
#  3   대출 기간                1228705 non-null  float64
#  4   월 상환액                1228705 non-null  float64
#  5   등급                   1228705 non-null  float64
#  6   근무 기간 (년)            1228705 non-null  float64
#  7   주택 소유 상태             1228705 non-null  float64
#  8   연간 소득                1228705 non-null  float64
#  9   부채 대비 소득 비율          1227389 non-null  float64
#  10  FICO 하한선             1228705 non-null  float64
#  11  FICO 상한선             1228705 non-null  float64
#  12  현재 활성 신용 계좌 수        1228695 non-null  float64
#  13  공공 기록 수              1228695 non-null  float64
#  14  회전 신용 잔액             1228705 non-null  float64
#  15  회전 계좌 사용 비율          1228705 non-null  float64
#  16  총 계좌 수               1228695 non-null  float64
#  17  지난 6개월간 활성 신용 계좌 수   865049 non-null   float64
#  18  활성 할부 계좌 수           865049 non-null   float64
#  19  지난 12개월간 할부 계좌 개설 수  865049 non-null   float64
#  20  최대 은행카드 잔액           865049 non-null   float64
#  21  신청 유형                1228705 non-null  float64
#  22  대출 목적                1228705 non-null  float64
#  23  최초 신용 계좌 개설일         1228705 non-null  float64
#  24  회전 신용 고한도 총액         1199277 non-null  float64
#  25  현재 연체 계좌 수           1228695 non-null  float64
#  26  최근 연체 후 경과 개월 수      582886 non-null   float64
# dtypes: float64(27)
# memory usage: 262.5 MB
# None
#
# X_test 데이터프레임의 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 526589 entries, 1746261 to 447608
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   대출 신청 금액             526589 non-null  float64
#  1   대출 금액                526589 non-null  float64
#  2   이자율                  526589 non-null  float64
#  3   대출 기간                526589 non-null  float64
#  4   월 상환액                526589 non-null  float64
#  5   등급                   526589 non-null  float64
#  6   근무 기간 (년)            526589 non-null  float64
#  7   주택 소유 상태             526589 non-null  float64
#  8   연간 소득                526587 non-null  float64
#  9   부채 대비 소득 비율          526044 non-null  float64
#  10  FICO 하한선             526589 non-null  float64
#  11  FICO 상한선             526589 non-null  float64
#  12  현재 활성 신용 계좌 수        526583 non-null  float64
#  13  공공 기록 수              526583 non-null  float64
#  14  회전 신용 잔액             526589 non-null  float64
#  15  회전 계좌 사용 비율          526589 non-null  float64
#  16  총 계좌 수               526583 non-null  float64
#  17  지난 6개월간 활성 신용 계좌 수   370525 non-null  float64
#  18  활성 할부 계좌 수           370525 non-null  float64
#  19  지난 12개월간 할부 계좌 개설 수  370525 non-null  float64
#  20  최대 은행카드 잔액           370525 non-null  float64
#  21  신청 유형                526589 non-null  float64
#  22  대출 목적                526589 non-null  float64
#  23  최초 신용 계좌 개설일         526589 non-null  float64
#  24  회전 신용 고한도 총액         513930 non-null  float64
#  25  현재 연체 계좌 수           526583 non-null  float64
#  26  최근 연체 후 경과 개월 수      250210 non-null  float64
# dtypes: float64(27)
# memory usage: 112.5 MB
# None

# %%
# '최근 연체 후 경과 개월 수' 열 제외
selected_features.remove('최근 연체 후 경과 개월 수')

# selected_features에 따라 X_train과 X_test 재구성
X_train = X_train[selected_features].copy()
X_test = X_test[selected_features].copy()

# 결측치가 있는 행 제거
X_train_cleaned = X_train.dropna()
X_test_cleaned = X_test.dropna()

# 타겟 변수도 동일한 인덱스를 유지하도록 정리
y_train_cleaned = y_train.loc[X_train_cleaned.index]
y_test_cleaned = y_test.loc[X_test_cleaned.index]

# 데이터셋 상태 확인
print("결측치 제거 후 X_train_cleaned 정보:")
print(X_train_cleaned.info())
print("\n결측치 제거 후 X_test_cleaned 정보:")
print(X_test_cleaned.info())
print(f"\n결측치 제거 후 y_train_cleaned 크기: {y_train_cleaned.shape}, y_test_cleaned 크기: {y_test_cleaned.shape}")
# Out:
# 결측치 제거 후 X_train_cleaned 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 863734 entries, 1650117 to 121958
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   대출 신청 금액             863734 non-null  float64
#  1   대출 금액                863734 non-null  float64
#  2   이자율                  863734 non-null  float64
#  3   대출 기간                863734 non-null  float64
#  4   월 상환액                863734 non-null  float64
#  5   등급                   863734 non-null  float64
#  6   근무 기간 (년)            863734 non-null  float64
#  7   주택 소유 상태             863734 non-null  float64
#  8   연간 소득                863734 non-null  float64
#  9   부채 대비 소득 비율          863734 non-null  float64
#  10  FICO 하한선             863734 non-null  float64
#  11  FICO 상한선             863734 non-null  float64
#  12  현재 활성 신용 계좌 수        863734 non-null  float64
#  13  공공 기록 수              863734 non-null  float64
#  14  회전 신용 잔액             863734 non-null  float64
#  15  회전 계좌 사용 비율          863734 non-null  float64
#  16  총 계좌 수               863734 non-null  float64
#  17  지난 6개월간 활성 신용 계좌 수   863734 non-null  float64
#  18  활성 할부 계좌 수           863734 non-null  float64
#  19  지난 12개월간 할부 계좌 개설 수  863734 non-null  float64
#  20  최대 은행카드 잔액           863734 non-null  float64
#  21  신청 유형                863734 non-null  float64
#  22  대출 목적                863734 non-null  float64
#  23  최초 신용 계좌 개설일         863734 non-null  float64
#  24  회전 신용 고한도 총액         863734 non-null  float64
#  25  현재 연체 계좌 수           863734 non-null  float64
# dtypes: float64(26)
# memory usage: 177.9 MB
# None
#
# 결측치 제거 후 X_test_cleaned 정보:
# <class 'pandas.core.frame.DataFrame'>
# Index: 369980 entries, 235621 to 1384868
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   대출 신청 금액             369980 non-null  float64
#  1   대출 금액                369980 non-null  float64
#  2   이자율                  369980 non-null  float64
#  3   대출 기간                369980 non-null  float64
#  4   월 상환액                369980 non-null  float64
#  5   등급                   369980 non-null  float64
#  6   근무 기간 (년)            369980 non-null  float64
#  7   주택 소유 상태             369980 non-null  float64
#  8   연간 소득                369980 non-null  float64
#  9   부채 대비 소득 비율          369980 non-null  float64
#  10  FICO 하한선             369980 non-null  float64
#  11  FICO 상한선             369980 non-null  float64
#  12  현재 활성 신용 계좌 수        369980 non-null  float64
#  13  공공 기록 수              369980 non-null  float64
#  14  회전 신용 잔액             369980 non-null  float64
#  15  회전 계좌 사용 비율          369980 non-null  float64
#  16  총 계좌 수               369980 non-null  float64
#  17  지난 6개월간 활성 신용 계좌 수   369980 non-null  float64
#  18  활성 할부 계좌 수           369980 non-null  float64
#  19  지난 12개월간 할부 계좌 개설 수  369980 non-null  float64
#  20  최대 은행카드 잔액           369980 non-null  float64
#  21  신청 유형                369980 non-null  float64
#  22  대출 목적                369980 non-null  float64
#  23  최초 신용 계좌 개설일         369980 non-null  float64
#  24  회전 신용 고한도 총액         369980 non-null  float64
#  25  현재 연체 계좌 수           369980 non-null  float64
# dtypes: float64(26)
# memory usage: 76.2 MB
# None
#
# 결측치 제거 후 y_train_cleaned 크기: (863734,), y_test_cleaned 크기: (369980,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# Step 1: 로지스틱 회귀 모델 학습
logistic_model = LogisticRegression(max_iter=1000, random_state=42)
logistic_model.fit(X_train_cleaned, y_train_cleaned)

# 로지스틱 회귀 모델 예측
y_pred_logistic = logistic_model.predict(X_test_cleaned)

# 성능 평가 - 로지스틱 회귀
logistic_accuracy = accuracy_score(y_test_cleaned, y_pred_logistic)
print(f"로지스틱 회귀 모델 정확도: {logistic_accuracy:.4f}")
print("로지스틱 회귀 모델 혼동 행렬:")
print(confusion_matrix(y_test_cleaned, y_pred_logistic))
print("로지스틱 회귀 모델 분류 보고서:")
print(classification_report(y_test_cleaned, y_pred_logistic))
# Out:
# 로지스틱 회귀 모델 정확도: 0.6068
# 로지스틱 회귀 모델 혼동 행렬:
# [[143545    742  43473]
#  [ 18080   1807  17738]
#  [ 63919   1527  79149]]
# 로지스틱 회귀 모델 분류 보고서:
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.69    187760
#            1       0.44      0.05      0.09     37625
#            2       0.56      0.55      0.56    144595
#
#     accuracy                           0.61    369980
#    macro avg       0.55      0.45      0.45    369980
# weighted avg       0.59      0.61      0.58    369980

# %%
# 타겟 변수의 분포 확인
print(y_train.value_counts())
# Out:
# 대출 상태 그룹
# 2    628736
# 0    447437
# 1    152532
# Name: count, dtype: int64

# %%
# Step 1: 연체 상태를 제외한 데이터 필터링
# 타겟 변수에서 '연체' 상태에 해당하는 클래스 1을 제외합니다.
filtered_X_train = X_train_cleaned[y_train_cleaned != 1]
filtered_y_train = y_train_cleaned[y_train_cleaned != 1]

filtered_X_test = X_test_cleaned[y_test_cleaned != 1]
filtered_y_test = y_test_cleaned[y_test_cleaned != 1]

# %% [markdown]
# ## 클래스 불균형 좀 해결해보자..

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# SMOTE 적용
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(filtered_X_train, filtered_y_train)

# 랜덤 포레스트 모델 학습
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_res, y_train_res)

# 예측 및 평가
y_pred = rf_model.predict(filtered_X_test)
print("SMOTE 적용 후 랜덤 포레스트 모델 정확도:", accuracy_score(filtered_y_test, y_pred))
print("SMOTE 적용 후 랜덤 포레스트 모델 혼동 행렬:")
print(confusion_matrix(filtered_y_test, y_pred))
print("SMOTE 적용 후 랜덤 포레스트 모델 분류 보고서:")
print(classification_report(filtered_y_test, y_pred))
# Out:
# SMOTE 적용 후 랜덤 포레스트 모델 정확도: 0.7608701539017015
# SMOTE 적용 후 랜덤 포레스트 모델 혼동 행렬:
# [[155276  32484]
#  [ 46992  97603]]
# SMOTE 적용 후 랜덤 포레스트 모델 분류 보고서:
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80    187760
#            2       0.75      0.68      0.71    144595
#
#     accuracy                           0.76    332355
#    macro avg       0.76      0.75      0.75    332355
# weighted avg       0.76      0.76      0.76    332355

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE

# Step 1: 결측치가 있는 행 제거
filtered_X_train_cleaned = filtered_X_train.dropna()
filtered_X_test_cleaned = filtered_X_test.dropna()

# 타겟 변수도 동일한 인덱스를 유지하도록 정리
filtered_y_train_cleaned = filtered_y_train.loc[filtered_X_train_cleaned.index]
filtered_y_test_cleaned = filtered_y_test.loc[filtered_X_test_cleaned.index]

# Step 2: SMOTE 적용
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(filtered_X_train_cleaned, filtered_y_train_cleaned)

# Step 3: 로지스틱 회귀 모델 학습
logistic_model = LogisticRegression(max_iter=1000, random_state=42)
logistic_model.fit(X_train_res, y_train_res)

# Step 4: 모델 예측 및 평가
logistic_pred = logistic_model.predict(filtered_X_test_cleaned)

# 성능 평가 - 로지스틱 회귀
logistic_accuracy = accuracy_score(filtered_y_test_cleaned, logistic_pred)
print(f"로지스틱 회귀 모델 정확도: {logistic_accuracy:.4f}")
print("로지스틱 회귀 모델 혼동 행렬:")
print(confusion_matrix(filtered_y_test_cleaned, logistic_pred))
print("로지스틱 회귀 모델 분류 보고서:")
print(classification_report(filtered_y_test_cleaned, logistic_pred))
# Out:
# 로지스틱 회귀 모델 정확도: 0.6667
# 로지스틱 회귀 모델 혼동 행렬:
# [[123800  63960]
#  [ 46803  97792]]
# 로지스틱 회귀 모델 분류 보고서:
#               precision    recall  f1-score   support
#
#            0       0.73      0.66      0.69    187760
#            2       0.60      0.68      0.64    144595
#
#     accuracy                           0.67    332355
#    macro avg       0.67      0.67      0.66    332355
# weighted avg       0.67      0.67      0.67    332355

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Gradient Boosting 모델 학습
gb_model = GradientBoostingClassifier(random_state=42, n_estimators=100, learning_rate=0.1)
gb_model.fit(X_train_res, y_train_res)

# 예측 및 평가
y_pred_gb = gb_model.predict(filtered_X_test_cleaned)
print("Gradient Boosting 모델 정확도:", accuracy_score(filtered_y_test_cleaned, y_pred_gb))
print("Gradient Boosting 모델 혼동 행렬:")
print(confusion_matrix(filtered_y_test_cleaned, y_pred_gb))
print("Gradient Boosting 모델 분류 보고서:")
print(classification_report(filtered_y_test_cleaned, y_pred_gb))
# Out:
# Gradient Boosting 모델 정확도: 0.7319913947435723
# Gradient Boosting 모델 혼동 행렬:
# [[137755  50005]
#  [ 39069 105526]]
# Gradient Boosting 모델 분류 보고서:
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.76    187760
#            2       0.68      0.73      0.70    144595
#
#     accuracy                           0.73    332355
#    macro avg       0.73      0.73      0.73    332355
# weighted avg       0.74      0.73      0.73    332355

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: 독립 변수 간 상관관계 매트릭스 계산
correlation_matrix = X_train_cleaned.corr()

# Step 2: 상관관계 히트맵 시각화
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt='.2f', linewidths=0.5)
plt.title('독립 변수 간 상관관계 히트맵', fontsize=15)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.draw()
# /Users/damien/Library/Python/3.12/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) AppleGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Step 2.1: 상관계수 0.8 이상인 변수 쌍 선택
high_correlation_threshold = 0.8
high_corr_var_pairs = []

# 상관관계 매트릭스를 반복하여 상관관계가 높은 변수 쌍을 찾음
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > high_correlation_threshold:
            var1 = correlation_matrix.columns[i]
            var2 = correlation_matrix.columns[j]
            high_corr_var_pairs.append((var1, var2))

# 높은 상관관계를 가진 변수 쌍 출력
print(f"상관계수 {high_correlation_threshold} 이상인 변수 쌍: {high_corr_var_pairs}")
# Out:
# 상관계수 0.8 이상인 변수 쌍: [('대출 금액', '대출 신청 금액'), ('월 상환액', '대출 신청 금액'), ('월 상환액', '대출 금액'), ('등급', '이자율'), ('FICO 상한선', 'FICO 하한선')]

# %%
# Step 2.2: 종속 변수와의 상관관계 계산
target_correlation = X_train_cleaned.join(y_train_cleaned).corr()['대출 상태 그룹'].drop('대출 상태 그룹')

# 종속 변수와의 상관관계가 더 높은 변수를 유지
variables_to_remove = []
for var1, var2 in high_corr_var_pairs:
    if target_correlation[var1] > target_correlation[var2]:
        variables_to_remove.append(var2)
    else:
        variables_to_remove.append(var1)

# 변수 제거
X_train_reduced = X_train_cleaned.drop(columns=variables_to_remove)
X_test_reduced = X_test_cleaned.drop(columns=variables_to_remove)

# 제거된 변수 확인
print(f"제거된 변수들: {variables_to_remove}")
# Out:
# 제거된 변수들: ['대출 금액', '대출 신청 금액', '대출 금액', '이자율', 'FICO 하한선']

# %%
# 현재 모델에 포함된 독립변수 목록 확인
remaining_features = X_train_reduced.columns.tolist()

# 독립변수 목록 출력
print("현재 모델에 포함된 독립변수 목록:")
for feature in remaining_features:
    print(feature)
# Out:
# 현재 모델에 포함된 독립변수 목록:
# 대출 기간
# 월 상환액
# 등급
# 근무 기간 (년)
# 주택 소유 상태
# 연간 소득
# 부채 대비 소득 비율
# FICO 상한선
# 현재 활성 신용 계좌 수
# 공공 기록 수
# 회전 신용 잔액
# 회전 계좌 사용 비율
# 총 계좌 수
# 지난 6개월간 활성 신용 계좌 수
# 활성 할부 계좌 수
# 지난 12개월간 할부 계좌 개설 수
# 최대 은행카드 잔액
# 신청 유형
# 대출 목적
# 최초 신용 계좌 개설일
# 회전 신용 고한도 총액
# 현재 연체 계좌 수
